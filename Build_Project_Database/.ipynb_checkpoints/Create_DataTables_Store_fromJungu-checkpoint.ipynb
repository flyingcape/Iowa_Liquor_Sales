# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Iowa_Liquor_Sales.csv', 
                 dtype={"Invoice/Item Number": 'object', "Date": 'object', "Store Number": "int64",
                       "Store Name": 'object', "Address": 'object', "City": 'object', "Zip Code": 'object',
                       "Store Location": 'object', "County Number": 'float64', "County": 'object', "Category": 'float64',
                       "Category Name": 'object', "Vendor Number": 'float64', "Vender Name": 'object',
                       "Item Number": 'object', "Item Description": 'object', "Pack": 'int64', "Bottle Volumne (ml)": 'int64',
                       "State Bottle Cost": 'float64', "State Bottle Retail": 'float64', "Bottles Sold": 'int64',
                       "Sale (Dollars)": 'float64', "Volume Sold(Liters)": 'float64', "Volume Sold (Gallons)": 'float64'})
# Date column to be datetim64
# Zip code column includes non number type
# Non value should be in float64 type
# Item Number column includes non number type
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Invoice/Item Number              object
# Date                     datetime64[ns]
# Store Number                      int64
# Store Name                       object
# Address                          object
# City                             object
# Zip Code                         object
# Store Location                   object
# County Number                   float64
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                   float64
# Vendor Name                      object
# Item Number                      object
# Item Description                 object
# Pack                              int64
# Bottle Volume (ml)                int64
# State Bottle Cost               float64
# State Bottle Retail             float64
# Bottles Sold                      int64
# Sale (Dollars)                  float64
# Volume Sold (Liters)            float64
# Volume Sold (Gallons)           float64
# dtype: object

# %%
df.shape
# Out:
# (23154845, 24)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Store Location           2282212
# County Number             156873
# County                    156871
# Zip Code                   80113
# Address                    80069
# City                       80068
# Category Name              25040
# Category                   16974
# Sale (Dollars)                10
# State Bottle Retail           10
# State Bottle Cost             10
# Vendor Number                  9
# Vendor Name                    7
# Bottle Volume (ml)             0
# Volume Sold (Liters)           0
# Bottles Sold                   0
# Invoice/Item Number            0
# Pack                           0
# Item Description               0
# Item Number                    0
# Date                           0
# Store Name                     0
# Store Number                   0
# Volume Sold (Gallons)          0
# dtype: int64

# %%
# lowercase string values for data cleaning
for col in ['Store Name', 'Address', 'City', 'County', 'Category Name', 'Vendor Name', 'Item Description']:
    df[col] = df[col].str.lower()

# %%
df.head()
# Out:
#   Invoice/Item Number       Date  Store Number  \
# 0        S32145600055 2016-05-04          4197
# 1        S32136600002 2016-05-04          4156
# 2        S32210100074 2016-05-09          4312
# 3        S32141700031 2016-05-04          4169
# 4        S32204800017 2016-05-09          4596
#
#                              Store Name            Address            City  \
# 0  fareway stores #014 / sergeant bluff        700  1st st  sergeant bluff
# 1         fareway stores #412 / oelwein    102  2nd ave se         oelwein
# 2          i-80 liquor / council bluffs  2411 s 24th st #1  council bluffs
# 3               super quick 2 / hubbell   1824 hubbell ave      des moines
# 4      quik trip #534 / e university dm  2945 e university      des moines
#
#   Zip Code                Store Location  County Number         County  \
# 0    51054  POINT (-96.353078 42.400504)           97.0       woodbury
# 1    50662  POINT (-91.910502 42.677024)           33.0        fayette
# 2    51501    POINT (-95.8792 41.238092)           78.0  pottawattamie
# 3    50317                           NaN            NaN            NaN
# 4    50317  POINT (-93.558972 41.600468)           77.0           polk
#
#     Category                     Category Name  Vendor Number  \
# 0  1031080.0                    vodka 80 proof          434.0
# 1  1081600.0                   whiskey liqueur          380.0
# 2  1062200.0  puerto rico & virgin islands rum          434.0
# 3  1081600.0                   whiskey liqueur          421.0
# 4  1031080.0                    vodka 80 proof          300.0
#
#                     Vendor Name Item Number           Item Description  Pack  \
# 0                luxco-st louis       36308              hawkeye vodka     6
# 1     phillips beverage company       27585                  hot stuff    12
# 2                luxco-st louis       45277        paramount white rum    12
# 3             sazerac co., inc.       64867  fireball cinnamon whiskey    12
# 4  mccormick distilling company       36903            mccormick vodka    48
#
#    Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 0                1750               7.17                10.76            24
# 1                 750               7.15                10.73            12
# 2                1000               4.42                 6.63             1
# 3                1000              11.34                17.01             2
# 4                 200               1.13                 1.70             9
#
#    Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)
# 0          258.24                  42.0                  11.10
# 1          128.76                   9.0                   2.38
# 2            6.63                   1.0                   0.26
# 3           34.02                   2.0                   0.53
# 4           15.30                   1.8                   0.48

# %%
df_store = df[['Store Number', 'Store Name', 'Address', 'City', 'Zip Code', 'Store Location', 'County Number', 'County']]

# %% [markdown]
# > - Fill in NA values

# %%
df_store.isna().sum()
# Out:
# Store Number            0
# Store Name              0
# Address             80069
# City                80068
# Zip Code            80113
# Store Location    2282212
# County Number      156873
# County             156871
# dtype: int64

# %%
for col in ['Store Name', 'Address', 'City', 'Zip Code', 'Store Location', 'County Number', 'County']:

    # for missing values in the column, find if there's existing value in another observation
    for SN in df_store[df_store[col].isna()]['Store Number'].unique():

        # Does another observation have same store number with column information?
        try:
            actual_value = df_store[(df_store['Store Number'] == SN) & (df_store[col].notnull())][col].unique()[0]
            df_store.loc[(df_store['Store Number'] == SN) & (df_store[col].isna()), col] = actual_value

        # No reference for address
        except IndexError:
            pass
            print("Can't find ", col," information of store Number ", SN, " in other observations")
df_store.isna().sum()
# Out:
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Can't find  Address  information of store Number  5320  in other observations
# Can't find  Address  information of store Number  9932  in other observations
# Can't find  City  information of store Number  5320  in other observations
# Can't find  Zip Code  information of store Number  5320  in other observations
# Can't find  Store Location  information of store Number  4169  in other observations
# Can't find  Store Location  information of store Number  2560  in other observations
# Can't find  Store Location  information of store Number  2549  in other observations
# Can't find  Store Location  information of store Number  2625  in other observations
# Can't find  Store Location  information of store Number  3417  in other observations
# Can't find  Store Location  information of store Number  3993  in other observations
# Can't find  Store Location  information of store Number  2551  in other observations
# Can't find  Store Location  information of store Number  2513  in other observations
# Can't find  Store Location  information of store Number  4255  in other observations
# Can't find  Store Location  information of store Number  3868  in other observations
# Can't find  Store Location  information of store Number  3584  in other observations
# Can't find  Store Location  information of store Number  2620  in other observations
# Can't find  Store Location  information of store Number  2522  in other observations
# Can't find  Store Location  information of store Number  4498  in other observations
# Can't find  Store Location  information of store Number  3762  in other observations
# Can't find  Store Location  information of store Number  5142  in other observations
# Can't find  Store Location  information of store Number  2535  in other observations
# Can't find  Store Location  information of store Number  5257  in other observations
# Can't find  Store Location  information of store Number  4633  in other observations
# Can't find  Store Location  information of store Number  2643  in other observations
# Can't find  Store Location  information of store Number  2524  in other observations
# Can't find  Store Location  information of store Number  2459  in other observations
# Can't find  Store Location  information of store Number  4019  in other observations
# Can't find  Store Location  information of store Number  3912  in other observations
# Can't find  Store Location  information of store Number  5004  in other observations
# Can't find  Store Location  information of store Number  5098  in other observations
# Can't find  Store Location  information of store Number  5153  in other observations
# Can't find  Store Location  information of store Number  3857  in other observations
# Can't find  Store Location  information of store Number  3651  in other observations
# Can't find  Store Location  information of store Number  5107  in other observations
# Can't find  Store Location  information of store Number  4962  in other observations
# Can't find  Store Location  information of store Number  3705  in other observations
# Can't find  Store Location  information of store Number  4251  in other observations
# Can't find  Store Location  information of store Number  4222  in other observations
# Can't find  Store Location  information of store Number  4410  in other observations
# Can't find  Store Location  information of store Number  4150  in other observations
# Can't find  Store Location  information of store Number  4552  in other observations
# Can't find  Store Location  information of store Number  4752  in other observations
# Can't find  Store Location  information of store Number  5151  in other observations
# Can't find  Store Location  information of store Number  4641  in other observations
# Can't find  Store Location  information of store Number  3772  in other observations
# Can't find  Store Location  information of store Number  4334  in other observations
# Can't find  Store Location  information of store Number  3855  in other observations
# Can't find  Store Location  information of store Number  4726  in other observations
# Can't find  Store Location  information of store Number  2445  in other observations
# Can't find  Store Location  information of store Number  4130  in other observations
# Can't find  Store Location  information of store Number  5088  in other observations
# Can't find  Store Location  information of store Number  5025  in other observations
# Can't find  Store Location  information of store Number  3054  in other observations
# Can't find  Store Location  information of store Number  4638  in other observations
# Can't find  Store Location  information of store Number  2566  in other observations
# Can't find  Store Location  information of store Number  4562  in other observations
# Can't find  Store Location  information of store Number  5057  in other observations
# Can't find  Store Location  information of store Number  2478  in other observations
# Can't find  Store Location  information of store Number  4014  in other observations
# Can't find  Store Location  information of store Number  3968  in other observations
# Can't find  Store Location  information of store Number  4382  in other observations
# Can't find  Store Location  information of store Number  4684  in other observations
# Can't find  Store Location  information of store Number  5135  in other observations
# Can't find  Store Location  information of store Number  2848  in other observations
# Can't find  Store Location  information of store Number  2839  in other observations
# Can't find  Store Location  information of store Number  4504  in other observations
# Can't find  Store Location  information of store Number  4337  in other observations
# Can't find  Store Location  information of store Number  4176  in other observations
# Can't find  Store Location  information of store Number  4437  in other observations
# Can't find  Store Location  information of store Number  3930  in other observations
# Can't find  Store Location  information of store Number  5249  in other observations
# Can't find  Store Location  information of store Number  5181  in other observations
# Can't find  Store Location  information of store Number  4385  in other observations
# Can't find  Store Location  information of store Number  3882  in other observations
# Can't find  Store Location  information of store Number  4732  in other observations
# Can't find  Store Location  information of store Number  5103  in other observations
# Can't find  Store Location  information of store Number  5201  in other observations
# Can't find  Store Location  information of store Number  5104  in other observations
# Can't find  Store Location  information of store Number  4551  in other observations
# Can't find  Store Location  information of store Number  4714  in other observations
# Can't find  Store Location  information of store Number  5183  in other observations
# Can't find  Store Location  information of store Number  5273  in other observations
# Can't find  Store Location  information of store Number  5284  in other observations
# Can't find  Store Location  information of store Number  5436  in other observations
# Can't find  Store Location  information of store Number  5200  in other observations
# Can't find  Store Location  information of store Number  5286  in other observations
# Can't find  Store Location  information of store Number  5288  in other observations
# Can't find  Store Location  information of store Number  5501  in other observations
# Can't find  Store Location  information of store Number  5511  in other observations
# Can't find  Store Location  information of store Number  5338  in other observations
# Can't find  Store Location  information of store Number  5636  in other observations
# Can't find  Store Location  information of store Number  5359  in other observations
# Can't find  Store Location  information of store Number  5447  in other observations
# Can't find  Store Location  information of store Number  5465  in other observations
# Can't find  Store Location  information of store Number  5390  in other observations
# Can't find  Store Location  information of store Number  5352  in other observations
# Can't find  Store Location  information of store Number  5637  in other observations
# Can't find  Store Location  information of store Number  5484  in other observations
# Can't find  Store Location  information of store Number  5529  in other observations
# Can't find  Store Location  information of store Number  4656  in other observations
# Can't find  Store Location  information of store Number  5336  in other observations
# Can't find  Store Location  information of store Number  5396  in other observations
# Can't find  Store Location  information of store Number  5424  in other observations
# Can't find  Store Location  information of store Number  5459  in other observations
# Can't find  Store Location  information of store Number  5650  in other observations
# Can't find  Store Location  information of store Number  5400  in other observations
# Can't find  Store Location  information of store Number  5616  in other observations
# Can't find  Store Location  information of store Number  5320  in other observations
# Can't find  Store Location  information of store Number  5664  in other observations
# Can't find  Store Location  information of store Number  5381  in other observations
# Can't find  Store Location  information of store Number  5698  in other observations
# Can't find  Store Location  information of store Number  5709  in other observations
# Can't find  Store Location  information of store Number  2679  in other observations
# Can't find  Store Location  information of store Number  3911  in other observations
# Can't find  Store Location  information of store Number  2503  in other observations
# Can't find  Store Location  information of store Number  4099  in other observations
# Can't find  Store Location  information of store Number  4403  in other observations
# Can't find  Store Location  information of store Number  4075  in other observations
# Can't find  Store Location  information of store Number  2951  in other observations
# Can't find  Store Location  information of store Number  3908  in other observations
# Can't find  Store Location  information of store Number  4139  in other observations
# Can't find  Store Location  information of store Number  4567  in other observations
# Can't find  Store Location  information of store Number  3615  in other observations
# Can't find  Store Location  information of store Number  3760  in other observations
# Can't find  Store Location  information of store Number  4618  in other observations
# Can't find  Store Location  information of store Number  4282  in other observations
# Can't find  Store Location  information of store Number  4225  in other observations
# Can't find  Store Location  information of store Number  4262  in other observations
# Can't find  Store Location  information of store Number  4776  in other observations
# Can't find  Store Location  information of store Number  4066  in other observations
# Can't find  Store Location  information of store Number  2161  in other observations
# Can't find  Store Location  information of store Number  2681  in other observations
# Can't find  Store Location  information of store Number  9042  in other observations
# Can't find  Store Location  information of store Number  5782  in other observations
# Can't find  Store Location  information of store Number  5757  in other observations
# Can't find  Store Location  information of store Number  5814  in other observations
# Can't find  Store Location  information of store Number  5807  in other observations
# Can't find  Store Location  information of store Number  2686  in other observations
# Can't find  Store Location  information of store Number  6138  in other observations
# Can't find  Store Location  information of store Number  6118  in other observations
# Can't find  Store Location  information of store Number  6178  in other observations
# Can't find  Store Location  information of store Number  5874  in other observations
# Can't find  Store Location  information of store Number  5920  in other observations
# Can't find  Store Location  information of store Number  6137  in other observations
# Can't find  Store Location  information of store Number  5906  in other observations
# Can't find  Store Location  information of store Number  6199  in other observations
# Can't find  Store Location  information of store Number  6104  in other observations
# Can't find  Store Location  information of store Number  6134  in other observations
# Can't find  Store Location  information of store Number  2723  in other observations
# Can't find  Store Location  information of store Number  5884  in other observations
# Can't find  Store Location  information of store Number  5991  in other observations
# Can't find  Store Location  information of store Number  6078  in other observations
# Can't find  Store Location  information of store Number  6064  in other observations
# Can't find  Store Location  information of store Number  6001  in other observations
# Can't find  Store Location  information of store Number  5954  in other observations
# Can't find  Store Location  information of store Number  6166  in other observations
# Can't find  Store Location  information of store Number  6146  in other observations
# Can't find  Store Location  information of store Number  6214  in other observations
# Can't find  Store Location  information of store Number  6208  in other observations
# Can't find  Store Location  information of store Number  6133  in other observations
# Can't find  Store Location  information of store Number  5943  in other observations
# Can't find  Store Location  information of store Number  5947  in other observations
# Can't find  County Number  information of store Number  5220  in other observations
# Can't find  County Number  information of store Number  5320  in other observations
# Can't find  County Number  information of store Number  9936  in other observations
# Can't find  County  information of store Number  5220  in other observations
# Can't find  County  information of store Number  5320  in other observations
# Store Number            0
# Store Name              0
# Address               848
# City                  847
# Zip Code              847
# Store Location    1643162
# County Number        1646
# County               1644
# dtype: int64

# %% [markdown]
# - Drop off the store number 5320 and 9932 as we can't find the address information
# - That's 848 from 23M records

# %%
df_store.drop(df_store.loc[(df_store['Store Number'] == 5320) | (df_store['Store Number'] == 9932)].index, inplace=True)
print(len(df_store))
df_store.isna().sum()
# Out:
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 23153997
# Store Number            0
# Store Name              0
# Address                 0
# City                    0
# Zip Code                0
# Store Location    1642315
# County Number         799
# County                797
# dtype: int64

# %% [markdown]
# - The left Store Location and County NA values can be filled later with geocoding

# %% [markdown]
# > - Find values that existed more than 2 for one store number and make it one value

# %% [markdown]
# - 1: Store Number vs Store Name

# %%
print('The number of store number is ', len(df_store['Store Number'].unique()) )
print('The number of store name is ', len(df_store['Store Name'].unique()) )
# Out:
# The number of store number is  2691
# The number of store name is  2814

# %%
# groupby store number and store name 
df_numbername = df_store.groupby(['Store Number', 'Store Name']).agg({'County':'count'}).reset_index()

# sort only duplicated store number
# It means one store number has multiple store names
df_numbername_duplicates = df_numbername[df_numbername['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])

# unite the name for each store number
for SN in df_numbername_duplicates['Store Number'].unique():
    
    # find the store name that has the most transactions
    max_idx = df_numbername_duplicates[df_numbername_duplicates['Store Number'] == SN]['County'].idxmax()
    actual_name = df_numbername_duplicates.loc[max_idx,'Store Name']
    
    # change the names with the most frequent name per store number
    df_store.loc[(df_store['Store Number'] == SN) & (df_store['Store Name'] != actual_name), 'Store Name'] = actual_name

# different stores have same name    
print('The number of store number is ', len(df_store['Store Number'].unique()) )
print('The number of store name is ', len(df_store['Store Name'].unique()) )
# Out:
# The number of store number is  2691
# The number of store name is  2568

# %% [markdown]
# - 2: Store Number vs Address

# %%
# find address with the latest invoice and replace it IF the addresses are in the same county
# groupby store number, county and address 
df_numberadd = df_store.groupby(['Store Number', 'County', 'Address']).agg({'County Number':'count'}).reset_index()
df_numberadd_duplicates = df_numberadd[df_numberadd['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])
df_numberadd_duplicates
# Out:
#       Store Number       County                       Address  County Number
# 14            2238         polk               305 34th ave nw            765
# 15            2238         polk         3200 adventureland dr           3209
# 19            2290   buena vist            215 west milwaukee           1204
# 20            2290  buena vista            215 west milwaukee          37793
# 26            2445   pottawatta             504 south highway          10227
# ...            ...          ...                           ...            ...
# 2597          5971        mills              924 s. locust st           4976
# 2835          6229   buena vist              205 e 7th street            819
# 2836          6229   buena vist               208 e milwaukee            423
# 2884          9911         polk  3100 se grimes blvd. ste 100            980
# 2885          9911         polk                501 7th ave se           1005
#
# [420 rows x 4 columns]

# %%
len(df_store['County'].unique())
# Out:
# 105

# %% [markdown]
# - As the result, we have 105 unique county values when the actual should be 100 (99 counties + non value)

# %%
county_unique = df_store[df_store['County'].notnull()]['County'].unique()
county_unique.sort()
print(county_unique)
# Out:
# ['adair' 'adams' 'allamakee' 'appanoose' 'audubon' 'benton' 'black hawk'
#  'boone' 'bremer' 'buchanan' 'buena vist' 'buena vista' 'butler' 'calhoun'
#  'carroll' 'cass' 'cedar' 'cerro gord' 'cerro gordo' 'cherokee'
#  'chickasaw' 'clarke' 'clay' 'clayton' 'clinton' 'crawford' 'dallas'
#  'davis' 'decatur' 'delaware' 'des moines' 'dickinson' 'dubuque' 'el paso'
#  'emmet' 'fayette' 'floyd' 'franklin' 'fremont' 'greene' 'grundy'
#  'guthrie' 'hamilton' 'hancock' 'hardin' 'harrison' 'henry' 'howard'
#  'humboldt' 'ida' 'iowa' 'jackson' 'jasper' 'jefferson' 'johnson' 'jones'
#  'keokuk' 'kossuth' 'lee' 'linn' 'louisa' 'lucas' 'lyon' 'madison'
#  'mahaska' 'marion' 'marshall' 'mills' 'mitchell' 'monona' 'monroe'
#  'montgomery' 'muscatine' "o'brien" 'obrien' 'osceola' 'page' 'palo alto'
#  'plymouth' 'pocahontas' 'polk' 'pottawatta' 'pottawattamie' 'poweshiek'
#  'ringgold' 'sac' 'scott' 'shelby' 'sioux' 'story' 'tama' 'taylor' 'union'
#  'van buren' 'wapello' 'warren' 'washington' 'wayne' 'webster' 'winnebago'
#  'winneshiek' 'woodbury' 'worth' 'wright']

# %% [markdown]
# buena vist >>>>>>> buena vista
# cerro gord >>>>>>> cerro gordo
# el paso >>>>>>>>>> not in Iowa
# obrien >>>>>>>>>>> o'brien
# pottawatta >>>>>>> pottawattamie

# %%
# outliers because 'el paso' county is in CO
# to be dropped off
df_store[df_store['County'] == 'el paso']
# Out:
#          Store Number       Store Name                 Address  \
# 1895613          9936  dash events llc  1685 w uintah st. #101
# 1909714          9936  dash events llc  1685 w uintah st. #101
#
#                      City Zip Code                 Store Location  \
# 1895613  colorado springs    80904  POINT (-104.845334 38.848017)
# 1909714  colorado springs    80904  POINT (-104.845334 38.848017)
#
#          County Number   County
# 1895613            NaN  el paso
# 1909714            NaN  el paso

# %%
# change the typo county names
df_store['County'] = df_store['County'].replace({'buena vist':'buena vista', 'cerro gord':'cerro gordo', 'obrien':"o'brien", 'pottawatta':'pottawattamie'})

# drop off 'el paso' county values
df_store.drop(df_store.loc[df_store['County'] == 'el paso'].index, inplace=True)

len(df_store['County'].unique())
# Out:
# C:\Users\Jungu\AppData\Local\Temp/ipykernel_4064/3447016975.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_store['County'] = df_store['County'].replace({'buena vist':'buena vista', 'cerro gord':'cerro gordo', 'obrien':"o'brien", 'pottawatta':'pottawattamie'})
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 100

# %% [markdown]
# - Now, retry to groupby for store number vs address with county

# %%
df_numberadd = df_store.groupby(['Store Number', 'County', 'Address']).agg({'County Number':'count'}).reset_index()
df_numberadd_duplicates = df_numberadd[df_numberadd['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])
df_numberadd_duplicates
# Out:
#       Store Number       County                       Address  County Number
# 14            2238         polk               305 34th ave nw            765
# 15            2238         polk         3200 adventureland dr           3209
# 53            2523    appanoose                 414 n 18th st          26311
# 54            2523    appanoose                    609 n 18th           9071
# 65            2539       hardin                    640 s. oak          14845
# ...            ...          ...                           ...            ...
# 2510          5971        mills              924 s. locust st           4976
# 2748          6229  buena vista              205 e 7th street            819
# 2749          6229  buena vista               208 e milwaukee            423
# 2797          9911         polk  3100 se grimes blvd. ste 100            980
# 2798          9911         polk                501 7th ave se           1005
#
# [249 rows x 4 columns]

# %%
# get the latest invoice date per each store number
for SN in df_numberadd_duplicates['Store Number'].unique():
    
    # Check if the county is still same
    if len(df_numberadd_duplicates[df_numberadd_duplicates['Store Number'] == SN]['County'].unique()) == 1:

        # get the index for the latest invoice date
        max_idx = df[df['Store Number'] == SN]['Date'].idxmax()
        latest_add = df.loc[max_idx,'Address']

        # change the address with the latest
        df_store.loc[(df_store['Store Number'] == SN) & (df_store['Address'] != latest_add), 'Address'] = latest_add
    
    else:
        print(SN, 'moved to different county')
# Out:
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 2656 moved to different county
# 3461 moved to different county
# 4067 moved to different county
# 4320 moved to different county
# 4944 moved to different county

# %%
# df_numberadd[df_numberadd['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])
df_store[df_store['Store Number'] == 2656].drop_duplicates() # adams county
df_store[df_store['Store Number'] == 3461].drop_duplicates() # adair county
df_store[df_store['Store Number'] == 4067].drop_duplicates() # washington county
df_store[df_store['Store Number'] == 4320].drop_duplicates() # dallas county
df_store[df_store['Store Number'] == 4944].drop_duplicates() # warren county
# Out:
#         Store Number                   Store Name      Address         City  \
# 404276          4944  jiffy express / martensdale  290, hwy 28  martensdale
# 887721          4944  jiffy express / martensdale  290, hwy 28  martensdale
#
#        Zip Code                Store Location  County Number    County
# 404276    50160  POINT (-93.737459 41.373366)           91.0    warren
# 887721    50160  POINT (-93.737459 41.373366)           64.0  marshall

# %%
# change the wrong input county names
df_store.loc[(df_store['Store Number'] == 2656) & (df_store['County'] != 'adams'), 'County'] = 'adams'
df_store.loc[(df_store['Store Number'] == 3461) & (df_store['County'] != 'adair'), 'County'] = 'adair'
df_store.loc[(df_store['Store Number'] == 4067) & (df_store['County'] != 'washington'), 'County'] = 'washington'
df_store.loc[(df_store['Store Number'] == 4320) & (df_store['County'] != 'dallas'), 'County'] = 'dallas'
df_store.loc[(df_store['Store Number'] == 4944) & (df_store['County'] != 'warren'), 'County'] = 'warren'
# Out:
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_numberadd = df_store.groupby(['Store Number', 'County', 'Address']).agg({'County Number':'count'}).reset_index()
df_numberadd_duplicates = df_numberadd[df_numberadd['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])
df_numberadd_duplicates
# Out:
#      Store Number County            Address  County Number
# 279          3461  adair  607 s division st           5868
# 280          3461  adair  611 s division st          13087

# %%
# Since we checked the store number 3461 and we know that it moved in the same county, update the address for the latest one

# get the index for the latest invoice date
max_idx = df[df['Store Number'] == 3461]['Date'].idxmax()
latest_add = df.loc[max_idx,'Address']

# change the address with the latest
df_store.loc[(df_store['Store Number'] == 3461) & (df_store['Address'] != latest_add), 'Address'] = latest_add
# Out:
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# - 3: Store Number vs City

# %%
df_numberadd = df_store.groupby(['Store Number', 'City']).agg({'County Number':'count'}).reset_index()
df_numberadd_duplicates = df_numberadd[df_numberadd['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])
df_numberadd_duplicates
# Out:
#       Store Number        City  County Number
# 64            2543     ottumwa          24304
# 65            2543     ottuwma          50386
# 114           2604     le mars          11126
# 115           2604      lemars          37335
# 280           3456  clear lake          60354
# 281           3456   clearlake          16991
# 388           3742     le mars           3223
# 389           3742      lemars           7784
# 408           3782  guttenburg           2593
# 407           3782  guttenberg          12623
# 429           3822  shueyville           6125
# 430           3822     swisher           7191
# 1109          4668  clear lake          10165
# 1110          4668   clearlake           2638
# 1734          5300     ottumwa            648
# 1735          5300      otumwa           1533
# 2682          9911      grimes            980
# 2683          9911   urbandale           1005

# %% [markdown]
# - except store number 3822, 9911, it's typo errors
# - 3822 : shueyville
# - 9911 : grimes

# %%
df_store.loc[(df_store['Store Number'] == 3822) & (df_store['City'] != 'shueyville'), 'City'] = 'shueyville'
df_store.loc[(df_store['Store Number'] == 9911) & (df_store['City'] != 'grimes'), 'City'] = 'grimes'
# Out:
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
len(df_store['City'].unique())
# Out:
# 462

# %%
city_unique = df_store[df_store['City'].notnull()]['City'].unique()
city_unique.sort()
print(city_unique)
# aronolds park >> arnold's park
# clearlake >> clear lake
# ft. atkinson >> fort atkinson
# grand mounds >> grand mound
# guttenburg >> guttenberg
# jewell >> jewell junction
# kellog >> kellogg
# leclaire >> le claire
# lemars >> le mars
# mt pleasant >> mount pleasant
# mt vernon >> mount vernon
# 'ottuwma' 'otumwa' >> ottumwa
# 'pleasant valley' >> bettendorf
# 'saint ansgar' >> st ansgar
# Out:
# ['ackley' 'adair' 'adel' 'afton' 'akron' 'albert city' 'albia' 'albion'
#  'alburnett' 'alden' 'algona' 'allerton' 'allison' 'alta' 'alta vista'
#  'alton' 'altoona' 'alvord' 'amana' 'ames' 'anamosa' 'anita' 'ankeny'
#  'anthon' 'aplington' 'arlington' 'armstrong' "arnold's park"
#  'arnolds park' 'atkins' 'atlantic' 'audubon' 'aurelia' 'avoca' 'baldwin'
#  'bancroft' 'baxter' 'bedford' 'belle plaine' 'bellevue' 'belmond'
#  'bettendorf' 'bevington' 'blairstown' 'bloomfield' 'blue grass'
#  'bondurant' 'boone' 'boyden' 'britt' 'brooklyn' 'buffalo'
#  'buffalo center' 'burlington' 'bussey' 'calmar' 'camanche' 'cambridge'
#  'carlisle' 'carroll' 'carter lake' 'cascade' 'casey' 'cedar falls'
#  'cedar rapids' 'center point' 'centerville' 'central city' 'chariton'
#  'charles city' 'cherokee' 'chester' 'clarence' 'clarinda' 'clarion'
#  'clarksville' 'clear lake' 'clearlake' 'clermont' 'clinton' 'clive'
#  'coggon' 'colesburg' 'colfax' 'colo' 'columbus junction' 'conrad'
#  'coon rapids' 'coralville' 'corning' 'correctionville' 'corwith'
#  'corydon' 'council bluffs' 'crescent' 'cresco' 'creston' 'cumming'
#  'dakota city' 'dallas center' 'danville' 'davenport' 'dayton' 'de soto'
#  'decorah' 'delaware' 'delhi' 'delmar' 'denison' 'denver' 'des moines'
#  'dewitt' 'dexter' 'donnellson' 'doon' 'dows' 'dubuque' 'dumont' 'dunlap'
#  'durant' 'dyersville' 'dysart' 'eagle grove' 'earlham' 'earling' 'early'
#  'eddyville' 'edgewood' 'eldon' 'eldora' 'eldridge' 'elkader' 'ellsworth'
#  'elma' 'ely' 'emmetsburg' 'essex' 'estherville' 'evansdale' 'everly'
#  'exira' 'fairbank' 'fairfax' 'fairfield' 'farley' 'farmington' 'fayette'
#  'floyd' 'fonda' 'fontanelle' 'forest city' 'fort atkinson' 'fort dodge'
#  'fort madison' 'fredericksburg' 'fremont' 'ft. atkinson' 'garnavillo'
#  'garner' 'garwin' 'george' 'gilbertville' 'gilman' 'gilmore city'
#  'gladbrook' 'glenwood' 'glidden' 'goldfield' 'gowrie' 'graettinger'
#  'grand junction' 'grand mound' 'grand mounds' 'granger' 'greene'
#  'greenfield' 'grimes' 'grinnell' 'griswold' 'grundy center'
#  'guthrie center' 'guttenberg' 'guttenburg' 'hamburg' 'hampton' 'harlan'
#  'harpers ferry' 'hartley' 'hawarden' 'hazleton' 'hiawatha' 'hills'
#  'hinton' 'holstein' 'holy cross' 'hospers' 'hubbard' 'hudson' 'hull'
#  'humboldt' 'humeston' 'huxley' 'ida grove' 'independence' 'indianola'
#  'inwood' 'iowa city' 'iowa falls' 'ireton' 'jefferson' 'jesup' 'jewell'
#  'johnston' 'kalona' 'kanawha' 'kellog' 'kellogg' 'keokuk' 'keosauqua'
#  'keota' 'kingsley' 'knoxville' 'la porte city' 'lake city' 'lake mills'
#  'lake park' 'lake view' 'lamoni' 'lamont' 'lansing' 'larchwood' 'latimer'
#  'laurens' 'lawler' 'le claire' 'le grand' 'le mars' 'leclaire' 'lemars'
#  'lenox' 'leon' 'lime springs' 'lisbon' 'livermore' 'logan' 'lohrville'
#  'lonetree' 'lost nation' 'lovilia' 'luxemburg' 'madrid' 'malcom'
#  'malvern' 'manchester' 'manly' 'manning' 'manson' 'mapleton' 'maquoketa'
#  'marcus' 'marengo' 'marion' 'marquette' 'marshalltown' 'martelle'
#  'martensdale' 'mason city' 'maxwell' 'maynard' 'mcgregor'
#  'mechanicsville' 'mediapolis' 'melbourne' 'melcher-dallas' 'merrill'
#  'middletown' 'milford' 'milo' 'minden' 'missouri valley' 'mitchellville'
#  'monona' 'monroe' 'montezuma' 'monticello' 'montrose' 'moravia'
#  'morning sun' 'mount ayr' 'mount pleasant' 'mount vernon' 'moville'
#  'mt pleasant' 'mt vernon' 'murray' 'muscatine' 'nashua' 'neola' 'nevada'
#  'new hampton' 'new hartford' 'new london' 'new sharon' 'new virginia'
#  'newton' 'nichols' 'nora springs' 'north english' 'north liberty'
#  'northwood' 'norwalk' 'norway' 'oakland' 'odebolt' 'oelwein' 'ogden'
#  'okoboji' 'onawa' 'orange city' 'osage' 'osceola' 'oskaloosa' 'ossian'
#  'otho' 'ottumwa' 'ottuwma' 'otumwa' 'oxford' 'pacific junction' 'palo'
#  'panora' 'parkersburg' 'paullina' 'pella' 'peosta' 'perry'
#  'pleasant hill' 'pleasant valley' 'pleasantville' 'pocahontas'
#  'polk city' 'pomeroy' 'postville' 'prairie city' 'preston' 'primghar'
#  'princeton' 'raymond' 'red oak' 'redfield' 'reinbeck' 'remsen'
#  'riceville' 'riverside' 'robins' 'rock rapids' 'rock valley' 'rockford'
#  'rockwell' 'rockwell city' 'roland' 'rolfe' 'rudd' 'runnells' 'ruthven'
#  'sac city' 'sageville' 'saint ansgar' 'sanborn' 'schaller' 'schleswig'
#  'scranton' 'sergeant bluff' 'seymour' 'sheffield' 'shelby' 'sheldon'
#  'shellsburg' 'shenandoah' 'shueyville' 'sibley' 'sidney' 'sigourney'
#  'sioux center' 'sioux city' 'sioux rapids' 'slater' 'sloan' 'solon'
#  'spencer' 'spirit lake' 'springville' 'st ansgar' 'st charles' 'st lucas'
#  'stanton' 'stanwood' 'state center' 'storm lake' 'story city' 'stratford'
#  'strawberry point' 'stuart' 'sully' 'sumner' 'sutherland' 'swea city'
#  'swisher' 'tabor' 'tama' 'templeton' 'tiffin' 'tipton' 'toledo' 'traer'
#  'treynor' 'tripoli' 'truro' 'urbana' 'urbandale' 'van horne' 'van meter'
#  'victor' 'villisca' 'vinton' 'walcott' 'walford' 'walker' 'wall lake'
#  'walnut' 'wapello' 'washburn' 'washington' 'washta' 'waterloo' 'waukee'
#  'waukon' 'waverly' 'webster city' 'wellman' 'wellsburg' 'wesley'
#  'west bend' 'west branch' 'west burlington' 'west des moines'
#  'west liberty' 'west point' 'west union' 'what cheer' 'wheatland'
#  'whittemore' 'williamsburg' 'wilton' 'windsor heights' 'winfield'
#  'winterset' 'winthrop' 'woodbine' 'woodward' 'wyoming' 'zwingle']

# %%
df_store.loc[df_store['City'] == 'arnolds park', 'City'] = "arnold's park"
df_store.loc[df_store['City'] == 'clearlake', 'City'] = "clear lake"
df_store.loc[df_store['City'] == 'ft. atkinson', 'City'] = "fort atkinson"
df_store.loc[df_store['City'] == 'grand mounds', 'City'] = "grand mound"
df_store.loc[df_store['City'] == 'guttenburg', 'City'] = "guttenberg"
df_store.loc[df_store['City'] == 'jewell', 'City'] = "jewell junction"
df_store.loc[df_store['City'] == 'kellog', 'City'] = "kellogg"
df_store.loc[df_store['City'] == 'leclaire', 'City'] = "le claire"
df_store.loc[df_store['City'] == 'lemars', 'City'] = "le mars"
df_store.loc[df_store['City'] == 'mt pleasant', 'City'] = "mount pleasant"
df_store.loc[df_store['City'] == 'mt vernon', 'City'] = "mount vernon"
df_store.loc[(df_store['City'] == 'ottuwma') | (df_store['City'] == 'otumwa'), 'City'] = "ottumwa"
df_store.loc[df_store['City'] == 'pleasant valley', 'City'] = "bettendorf"
df_store.loc[df_store['City'] == 'saint ansgar', 'City'] = "st ansgar"

# %%
len(df_store['City'].unique())
# Out:
# 448

# %% [markdown]
# - 4: Store Number vs Zip Code

# %%
df_numberadd = df_store.groupby(['Store Number', 'Zip Code']).agg({'County Number':'count'}).reset_index()
df_numberadd_duplicates = df_numberadd[df_numberadd['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])
df_numberadd_duplicates
# Out:
#       Store Number Zip Code  County Number
# 46            2514    50129          13064
# 47            2514    52302           2103
# 156           2656    50841           5857
# 157           2656    51632          13006
# 415           3805    52084          16167
# 416           3805    52804           7340
# 898           4457    52240           3557
# 899           4457    52246           5765
# 1525          5091    52671           7208
# 1526          5091    52761           2342
# 1532          5097    52402           1050
# 1533          5097    52403           4972
# 2680          9911    50111            980
# 2681          9911    50322           1005

# %% [markdown]
# - 2514 - 52302
# - 2656 - 50841
# - 3805 - 52804
# - 4457 - 52246
# - 5091 - 52761
# - 5097 - 52403
# - 9911 - 50111

# %%
df_store.loc[(df_store['Store Number'] == 2514) & (df_store['Zip Code'] != 52302), 'Zip Code'] = 52302
df_store.loc[(df_store['Store Number'] == 2656) & (df_store['Zip Code'] != 50841), 'Zip Code'] = 50841
df_store.loc[(df_store['Store Number'] == 3805) & (df_store['Zip Code'] != 52804), 'Zip Code'] = 52804
df_store.loc[(df_store['Store Number'] == 4457) & (df_store['Zip Code'] != 52246), 'Zip Code'] = 52246
df_store.loc[(df_store['Store Number'] == 5091) & (df_store['Zip Code'] != 52761), 'Zip Code'] = 52761
df_store.loc[(df_store['Store Number'] == 5097) & (df_store['Zip Code'] != 52403), 'Zip Code'] = 52403
df_store.loc[(df_store['Store Number'] == 9911) & (df_store['Zip Code'] != 50111), 'Zip Code'] = 50111
# Out:
# C:\Users\Jungu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_numberadd = df_store.groupby(['Store Number', 'Zip Code']).agg({'County Number':'count'}).reset_index()
df_numberadd_duplicates = df_numberadd[df_numberadd['Store Number'].duplicated(keep = False)].sort_values(by=['Store Number'])
df_numberadd_duplicates
# Out:
# Empty DataFrame
# Columns: [Store Number, Zip Code, County Number]
# Index: []

# %%
df_store.isna().sum()
# Out:
# Store Number            0
# Store Name              0
# Address                 0
# City                    0
# Zip Code                0
# Store Location    1642315
# County Number         797
# County                797
# dtype: int64

# %%
df_store = df_store.drop(columns = ['Store Location', 'County Number'])

# %%
len(df['Store Number'].unique())
# Out:
# 2693

# %%
# we have removed 3 store numbers, so this is a good sign
df_store.drop_duplicates()
# Out:
#           Store Number                            Store Name  \
# 0                 4197  fareway stores #014 / sergeant bluff
# 1                 4156         fareway stores #412 / oelwein
# 2                 4312          i-80 liquor / council bluffs
# 3                 4169               super quick 2 / hubbell
# 4                 4596      quik trip #534 / e university dm
# ...                ...                                   ...
# 21567388          5899                 fort dodge smoke shop
# 21570404          5930                       east post rd bp
# 21858704          5947         johnson ave bp / cedar rapids
# 22698939          9946       rock river distillation company
# 22779548          5958                    bp fuel / waterloo
#
#                     Address            City Zip Code         County
# 0               700  1st st  sergeant bluff    51054       woodbury
# 1           102  2nd ave se         oelwein    50662        fayette
# 2         2411 s 24th st #1  council bluffs    51501  pottawattamie
# 3          1824 hubbell ave      des moines    50317           polk
# 4         2945 e university      des moines    50317           polk
# ...                     ...             ...      ...            ...
# 21567388     1923 5th ave s      fort dodge    50501        webster
# 21570404  1010 east post rd          marion    52302           linn
# 21858704   4830 johnson ave    cedar rapids    52405           linn
# 22698939      3294 170th st     rock rapids    51246           lyon
# 22779548   127 jefferson st        waterloo    50701     black hawk
#
# [2690 rows x 6 columns]

# %%
store_db = df_store.drop_duplicates().reset_index()
store_db = store_db.drop(columns = ['index'])

# %% [markdown]
# - input geo information with lat and lng

# %%
import json
import time
import urllib.error
import urllib.parse
import urllib.request

# The maps_key defined below isn't a valid Google Maps API key.
# You need to get your own API key.
# See https://developers.google.com/maps/documentation/timezone/get-api-key
API_KEY = "AIzaSyD8Csb3FCjo4fZGQLBEF-47nOllcgN0qUI"
GEOCODE_URL = "https://maps.googleapis.com/maps/api/geocode/json"

# %%
def geo_lat_lng(address):
    
    target_key = 'geometry'
    target_subkey = 'location'
    
    # Join the parts of the URL together into one string.
    params = urllib.parse.urlencode(
        {"address": address, "key": API_KEY,}
    )
    url = f"{GEOCODE_URL}?{params}"

    while True:
        try:
            # Get the API response.
            response = urllib.request.urlopen(url)
        except urllib.error.URLError:
            pass  # Fall through to the retry loop.
        else:
            # If we didn't get an IOError then parse the result.
            result = json.load(response)

            if result["status"] == "OK":
                return result["results"][0].get(target_key)[target_subkey]
            elif result["status"] != "UNKNOWN_ERROR":
                # Many API errors cannot be fixed by a retry, e.g. INVALID_REQUEST or
                # ZERO_RESULTS. There is no point retrying these requests.
                raise Exception(result["error_message"])

# %%
def geo_county(address):
    
    target_key = 'address_components'
    target_subkey = 3
    
    # Join the parts of the URL together into one string.
    params = urllib.parse.urlencode(
        {"address": address, "key": API_KEY,}
    )
    url = f"{GEOCODE_URL}?{params}"

    while True:
        try:
            # Get the API response.
            response = urllib.request.urlopen(url)
        except urllib.error.URLError:
            pass  # Fall through to the retry loop.
        else:
            # If we didn't get an IOError then parse the result.
            result = json.load(response)

            if result["status"] == "OK":
                temp_result = result["results"][0].get(target_key)
                temp_df = pd.DataFrame.from_dict(temp_result)
                return temp_df[temp_df['long_name'].str.contains('County')]['long_name']
            elif result["status"] != "UNKNOWN_ERROR":
                # Many API errors cannot be fixed by a retry, e.g. INVALID_REQUEST or
                # ZERO_RESULTS. There is no point retrying these requests.
                raise Exception(result["error_message"])

# %%
# combine address + city + state for geocode
store_db['Geo Address'] = store_db['Address'] + " "+ store_db['City'] + " IA"
store_db
# Out:
#       Store Number                            Store Name            Address  \
# 0             4197  fareway stores #014 / sergeant bluff        700  1st st
# 1             4156         fareway stores #412 / oelwein    102  2nd ave se
# 2             4312          i-80 liquor / council bluffs  2411 s 24th st #1
# 3             4169               super quick 2 / hubbell   1824 hubbell ave
# 4             4596      quik trip #534 / e university dm  2945 e university
# ...            ...                                   ...                ...
# 2685          5899                 fort dodge smoke shop     1923 5th ave s
# 2686          5930                       east post rd bp  1010 east post rd
# 2687          5947         johnson ave bp / cedar rapids   4830 johnson ave
# 2688          9946       rock river distillation company      3294 170th st
# 2689          5958                    bp fuel / waterloo   127 jefferson st
#
#                 City Zip Code         County  \
# 0     sergeant bluff    51054       woodbury
# 1            oelwein    50662        fayette
# 2     council bluffs    51501  pottawattamie
# 3         des moines    50317           polk
# 4         des moines    50317           polk
# ...              ...      ...            ...
# 2685      fort dodge    50501        webster
# 2686          marion    52302           linn
# 2687    cedar rapids    52405           linn
# 2688     rock rapids    51246           lyon
# 2689        waterloo    50701     black hawk
#
#                               Geo Address
# 0           700  1st st sergeant bluff IA
# 1              102  2nd ave se oelwein IA
# 2     2411 s 24th st #1 council bluffs IA
# 3          1824 hubbell ave des moines IA
# 4         2945 e university des moines IA
# ...                                   ...
# 2685         1923 5th ave s fort dodge IA
# 2686          1010 east post rd marion IA
# 2687     4830 johnson ave cedar rapids IA
# 2688         3294 170th st rock rapids IA
# 2689         127 jefferson st waterloo IA
#
# [2690 rows x 7 columns]

# %%
# lat 41.8780025, lng -93.097702 means it couldn't find the actual address but put center(?) coordinate of Iowa
geo_record = []
for addr in store_db['Geo Address']:
    print(addr)
    geo_record.append(geo_lat_lng(addr))
# Out:
# 700  1st st sergeant bluff IA
# 102  2nd ave se oelwein IA
# 2411 s 24th st #1 council bluffs IA
# 1824 hubbell ave des moines IA
# 2945 e university des moines IA
# 2605 blairs ferry rd ne cedar rapids IA
# 345 e 20th st dubuque IA
# 107 1st st e leon IA
# 1989 park st sheldon IA
# 1616 edgington eldora IA
# 2501 hubbell ave des moines IA
# 114 south  2nd  st cherokee IA
# 3600 business hwy 151 east marion IA
# 103, w walnut st williamsburg IA
# 119, main st north english IA
# 3205 north ankeny blvd ankeny IA
# 2801 commerce dr coralville IA
# 819 n grand ave spencer IA
# 6401, douglas ave urbandale IA
# 706 highway 57 parkersburg IA
# 6723 nw blvd unit 2 davenport IA
# 4100 university ave des moines IA
# 1823 e kimberly rd davenport IA
# 614, e erie st missouri valley IA
# 622 10th  st dewitt IA
# 104 market st audubon IA
# 7205 mills civic pkwy west des moines IA
# 3235 oakland road ne cedar rapids IA
# 626 lincoln way ames IA
# 4825 johnson ave nw cedar rapids IA
# 2635 adventureland dr altoona IA
# 3500 ingersoll ave des moines IA
# 1373 pierce st sioux city IA
# 201 idaho st glidden IA
# 4201 s. york st. sioux city IA
# 910 n jefferson indianola IA
# 3301 w kimberly rd davenport IA
# 915 short st decorah IA
# 2302 west first st cedar falls IA
# 804 nile kinnick dr adel IA
# 3301 gordon dr sioux city IA
# 4923 merle hay rd des moines IA
# 1843 johnson avenue, n.w. cedar rapids IA
# 1610 okoboji avenue milford IA
# 904  1st ave nw cedar rapids IA
# 1501 michigan ave des moines IA
# 1606 w locust st davenport IA
# 5925 university ave cedar falls IA
# 519 lincolnway nevada IA
# 1720 waterfront dr iowa city IA
# 705 e. second indianola IA
# 2890 devils glen road bettendorf IA
# 8701 douglas urbandale IA
# 1951 s main ave sioux center IA
# 1798 old stage rd decorah IA
# 228 n main st monticello IA
# 507 w 19th st sioux city IA
# 1422 flammang dr waterloo IA
# 1115 albia rd ottumwa IA
# 1125 n dodge st iowa city IA
# 2606 avenue l fort madison IA
# 2453 north court ottumwa IA
# 702 13th st belle plaine IA
# 708 2nd  ave  se cresco IA
# 3815, west kimberly rd davenport IA
# 4200 dodge st dubuque IA
# 1810 state st bettendorf IA
# 5750 merle hay road johnston IA
# 3780 state st bettendorf IA
# 2540 e euclid des moines IA
# 1111 se lincoln st bondurant IA
# 1005 e hickman rd waukee IA
# 2200 west kimberly davenport IA
# 1202 a ave east oskaloosa IA
# 727 west st grinnell IA
# 1010 e mitchell ave waterloo IA
# 3221 se 14th st des moines IA
# 3330 martin luther king jr pkwy des moines IA
# 1250 n lake st storm lake IA
# 2508 enterprise ave spirit lake IA
# 1033 central avenue estherville IA
# 1140 north jefferson st ottumwa IA
# 2839 e. university des moines IA
# 3000 sw 9th st des moines IA
# 2601 hwy 6 east iowa city IA
# 4343 merle hay rd des moines IA
# 3200 manawa dr council bluffs IA
# 380 33rd ave sw cedar rapids IA
# 311 main st mapleton IA
# 1505 south b ave nevada IA
# 28 e howard colfax IA
# 300 e main st cherokee IA
# 3120 rockingham rd davenport IA
# 1460 2nd ave des moines IA
# 218, 6th ave #101 des moines IA
# 2645 blairs ferry rd ne cedar rapids IA
# po box 261  310 w dillon marengo IA
# 1602 e 7th st atlantic IA
# 2111 park ave muscatine IA
# 806 laurel st creston IA
# 4035 mt vernon rd se cedar rapids IA
# 6301 university cedar falls IA
# 200  1st st east independence IA
# 1031 west st grinnell IA
# 2008  12th st emmetsburg IA
# 522 mulberry, suite a muscatine IA
# 4400 asbury rd dubuque IA
# 137 2nd ave se oelwein IA
# 401 east market st iowa city IA
# 212 sw kent greenfield IA
# 5800 northglen dr johnston IA
# 2771, 4th st sw mason city IA
# 1201 12th ave sw le mars IA
# 2800 e university ave des moines IA
# 1178 enterprise dr riverside IA
# 501 a ave vinton IA
# 1011  13th st north humboldt IA
# 1700 10th avenue n humboldt IA
# 901 south 4th st clinton IA
# 305 s 18th st centerville IA
# 407 w huron missouri valley IA
# 201 ralph st monroe IA
# 2004 8th  st coralville IA
# 400 locust st dubuque IA
# 120 n 3rd ave e newton IA
# 1101 main st po box 535 manson IA
# 1625 west 4th st waterloo IA
# 501 7th ave se cedar rapids IA
# 4220  16th ave sw cedar rapids IA
# 600 w main st anamosa IA
# 1215  141 st perry IA
# 214 myrtle st davenport IA
# 1101  73rd st windsor heights IA
# 412  1st ave coralville IA
# 1950 princeton dr grimes IA
# 1910 sw white birch circle ankeny IA
# 1111  8th st boone IA
# 7265 vista dr west des moines IA
# 1115, bluestem dr carlisle IA
# 5101 se 14th st des moines IA
# 2001 west court chariton IA
# 1975 franklin st waterloo IA
# 1025 e  1st st ankeny IA
# 505 boyson rd ne cedar rapids IA
# 417 main st lansing IA
# 102, w mayne st blue grass IA
# 619 e main st sac city IA
# 110 s roosevelt hwy 61 burlington IA
# 2225 central ave dubuque IA
# 1805 se 14th st des moines IA
# 4000 university waterloo IA
# 885 miller rd hiawatha IA
# 1501 first avenue east newton IA
# 300  10th st corning IA
# 120 e main st marshalltown IA
# 3601 29th ave sw cedar rapids IA
# 110 westgate dr maquoketa IA
# 11925 university ave clive IA
# 1921 keokuk st iowa city IA
# 4500 sergeant road sioux city IA
# 2827 hamilton blvd sioux city IA
# 1990 grand avenue west des moines IA
# 908 7th ave camanche IA
# 812  s 1st ave iowa city IA
# 512  8th se orange city IA
# 5491 business hwy 151 marion IA
# 1350 11th st nw clinton IA
# 2351 w locust davenport IA
# 1821 hamilton blvd sioux city IA
# 724 1st  st  se mount vernon IA
# 1504 park ave muscatine IA
# 1315 willis ave perry IA
# 210 east tower park dr waterloo IA
# 1011 s frederick m/a po bx 572 oelwein IA
# 640 s. oak iowa falls IA
# 5050 edgewood rd cedar rapids IA
# 623 s marion st remsen IA
# 1232 14th st eldora IA
# 640 lincolnway ames IA
# 1900, se 37th st grimes IA
# 215 west milwaukee storm lake IA
# 310 n 1st st iowa city IA
# 1030 blairs ferry rd ne cedar rapids IA
# 1901 broadway st iowa city IA
# 1004 w madison st washington IA
# 3800 w lincoln way ames IA
# 610 cedar st tipton IA
# 309 a ave west oskaloosa IA
# 1026 w river dr davenport IA
# 4121 fleur dr des moines IA
# 2181 logan ave waterloo IA
# 53 green st winterset IA
# 913 brown st po box 326 larchwood IA
# 113 se delaware ave ste 101 ankeny IA
# 811 broadway red oak IA
# 222 north clark street paullina IA
# 804 g ave grundy center IA
# 1905 highway 18 e algona IA
# 1737 ave h fort madison IA
# 2508 w broadway council bluffs IA
# 2600 hwy 71 spirit lake IA
# 2401, main emmetsburg IA
# 2395 nw arterial rd dubuque IA
# 715 lang creek ave grinnell IA
# 721 central avenue west hampton IA
# 409 nile kinnick dr adel IA
# 1309 w 2nd indianola IA
# 3101 floyd blvd sioux city IA
# 515 broadway st waterloo IA
# 3140 agency burlington IA
# 1107 se army post rd des moines IA
# 201 w 1st st sumner IA
# 1204 water st po box 177 alden IA
# 4151  4th st sw mason city IA
# 158 south elm avoca IA
# 711  16th ave se dyersville IA
# 62 5th st woodbine IA
# 1808 23rd st harlan IA
# 1600 university ave dubuque IA
# 7101 university ave windsor heights IA
# 316 main st manning IA
# 508, main st osage IA
# 610 n kansas ave north liberty IA
# 1256 iowa st dubuque IA
# 2330 wiley blvd sw cedar rapids IA
# 900, e  washington  st clarinda IA
# 300 18th st spirit lake IA
# 3221 se 14th st des moines IA
# 3425 ingersoll ave des moines IA
# 702, 1st ave e newton IA
# 2128 college st cedar falls IA
# 101 e 4th st wilton IA
# 1203 guthrie st de soto IA
# 279 collins road ne cedar rapids IA
# 107 n portland st po bx 222 bancroft IA
# 1429 park ave muscatine IA
# 4064 e 53rd st davenport IA
# 410 north ankeny blvd ankeny IA
# 305 airport rd ames IA
# 939 angular burlington IA
# 757 w broadway council bluffs IA
# 223 main st lake view IA
# 904 n 8th st clear lake IA
# 609 n 18th centerville IA
# 1002 se national dr ankeny IA
# 141 s jordan creek pkwy west des moines IA
# 4510 mortensen rd ames IA
# 2014 kitty hawk ave carroll IA
# 4625 se delaware ave ankeny IA
# 2923 brady st davenport IA
# 3019 rockingham road davenport IA
# 405 1st ave e newton IA
# 1025 north quincy ave ottumwa IA
# 807 grandview muscatine IA
# 1026 2nd ave sibley IA
# 203 welch ave ames IA
# 3300 10th ave marion IA
# 2713 s 24th st council bluffs IA
# 300, kirkwood ave iowa city IA
# 5811 elmore ave davenport IA
# 534 s duff ave ames IA
# 618 rossville road waukon IA
# 100 8th street sw altoona IA
# 1324, 1st ave e newton IA
# 106 s 16th st sac city IA
# 777 casino dr osceola IA
# 105 pearl st shellsburg IA
# 823  2nd st webster city IA
# 4016 indian hills dr sioux city IA
# 87 8th st n northwood IA
# 822 1st  ave coralville IA
# 429 veterans memorial council bluffs IA
# 733 16th ave se dyersville IA
# 300 north park dr keokuk IA
# 6365 stagecoach dr west des moines IA
# 4605 fleur drive des moines IA
# 1001  73rd st windsor heights IA
# 812, sixth  st sw cedar rapids IA
# 105 grand ave west des moines IA
# 5775 sunnybrook dr sioux city IA
# 5969 ashworth rd west des moines IA
# 2728 center st cedar falls IA
# hwy 9 & 71 spirit lake IA
# 145 university ave des moines IA
# 3003 north hwy 61 muscatine IA
# 1703 park ave muscatine IA
# 115 essie davison dr clarinda IA
# 644 220th st winthrop IA
# 2933 1st ave se cedar rapids IA
# 1761 independence ave waterloo IA
# 1825 e san marnan waterloo IA
# 106, w washington st jefferson IA
# 4415 douglas ave des moines IA
# 1230 3rd ave nw fort dodge IA
# 1908, clark st charles city IA
# 5500, e university ave pleasant hill IA
# 23148 hwy 5 centerville IA
# 103 e main decorah IA
# 7690 hickman rd windsor heights IA
# 801, e  charles  st oelwein IA
# 14 1/2 e elm pocahontas IA
# 101  115 st anamosa IA
# 100 e  oakdale blvd coralville IA
# 2400 4th st sw mason city IA
# 113 1st st nw buffalo center IA
# 4538 lower beaver rd des moines IA
# 2515 chamberlain ames IA
# 201 w burlington ave fairfield IA
# 7000 douglas ave urbandale IA
# 612 s highway 71 arnold's park IA
# 882, main st holy cross IA
# 901 kelly st charles city IA
# 1122 broadway emmetsburg IA
# 2310 hubbell ave des moines IA
# 115 e main st  po box 359 west branch IA
# 2315 mt vernon rd se cedar rapids IA
# 1320 e  euclid ave des moines IA
# 1136, e locust st davenport IA
# 715  1st ave s mount vernon IA
# 361  3rd st nw hartley IA
# 3400 edgewood rd sw cedar rapids IA
# 420 sherman st ackley IA
# 809 e 18th st cedar falls IA
# 3400 singing hills blvd sioux city IA
# 2323 w broadway council bluffs IA
# 100 euclid ave des moines IA
# 107, east grace chariton IA
# 3111 main keokuk IA
# 906, s main st woodward IA
# 2000 willey blvd sw cedar rapids IA
# 315 fletcher ave waterloo IA
# 2359 edgington ave eldora IA
# 309, w  washington st mount pleasant IA
# 600 7th ave sw tripoli IA
# 2920 w locust st davenport IA
# 619 s hwy 52 guttenberg IA
# 4815 maple drive pleasant hill IA
# 1700 valley west dr west des moines IA
# 1775 nw 86th st clive IA
# 2904 center point rd ne cedar rapids IA
# 2400 2nd ave muscatine IA
# 202 4th  st  n rockwell IA
# 502 5th street lake view IA
# 900 e main st manchester IA
# 2325 7th ave north n clear lake IA
# 2100 cedar plaza dr muscatine IA
# 105 e adams st creston IA
# 329 grand ave west des moines IA
# 1414 48th st fort madison IA
# 510 west mclane osceola IA
# 905 us highway 30 west carroll IA
# 405, madison ave ottumwa IA
# 302 1st st sergeant bluff IA
# 1141 n broadway council bluffs IA
# 124, w robins st graettinger IA
# 1451 22nd st west des moines IA
# 1203 5 st sioux city IA
# 2100, lafayette st waterloo IA
# 1023 south main centerville IA
# 1101 army post rd des moines IA
# 500  11th st spencer IA
# 1400 g  ave grundy center IA
# 3101 west kimberly rd davenport IA
# 351 gateway dr grimes IA
# 1940 venture dr ottumwa IA
# 114 n  center  st marshalltown IA
# 1401, buchanan st des moines IA
# 1126 highway 38 north tipton IA
# 606, n 15th st fort dodge IA
# 1420 w first st cedar falls IA
# 910 hwy 18 w clear lake IA
# 2506, 280th  st montrose IA
# 1905 east 7th st atlantic IA
# 103 franklin st monona IA
# 1023  9th st onawa IA
# 428 franklin st waterloo IA
# 500 main st ames IA
# 1202 east locust st carter lake IA
# 109 east 1st st ste b grimes IA
# 3338 center point rd ne cedar rapids IA
# 508 broadway st waterloo IA
# 111 duff ave ames IA
# 1606 camanche ave clinton IA
# 1434 des moines st ste 5 des moines IA
# 700  29 st sw waverly IA
# 455 edgewood rd nw cedar rapids IA
# 910 n 8th st w clear lake IA
# 425 e leclaire rd eldridge IA
# 1300 west burlington ave fairfield IA
# 2126 kimball ave waterloo IA
# 4585 156th st urbandale IA
# 268 8th ave wellman IA
# 3603 ne otterview circle ankeny IA
# 3500 dodge st dubuque IA
# 875  4th st sw mason city IA
# 1650 washington st pella IA
# 1111 holton dr le mars IA
# 123 e main st solon IA
# 18 n monroe ave mason city IA
# 603  e hwy 24 lawler IA
# 65, williams blvd fairfax IA
# 319 e hwy 3 goldfield IA
# 7220 hickman rd windsor heights IA
# 3036 1st ave south fort dodge IA
# 111 e jefferson st winterset IA
# 735 main st anita IA
# 585 highway 965 north liberty IA
# 328  2nd ave s fort dodge IA
# 745 s 51st st west des moines IA
# 20 south 4th st clear lake IA
# 113, ne 3rd st panora IA
# 106 w 2nd st washington IA
# 306 hwy 69 south forest city IA
# 3632, avenue g council bluffs IA
# 1117 e 4th st waterloo IA
# 324 west agency rd west burlington IA
# 200 state po box 98 guthrie center IA
# 1502 highway 169 n suite 1 algona IA
# 1441 coral ridge ave coralville IA
# 8 2nd st nw britt IA
# 433 n farley st monticello IA
# 185, peosta st peosta IA
# 1100 greene st de soto IA
# 11148 plum dr urbandale IA
# 1641 s bluff blvd clinton IA
# 402 e 6th st carroll IA
# 702 e gilman st sheffield IA
# 4200 e hubbell ave des moines IA
# 5225 elmore ave davenport IA
# 244 w 4th st st ansgar IA
# 1115 ia hwy 141 perry IA
# 3499, 7th ave marion IA
# 555 s 51st st west des moines IA
# 437, sullivan ave waterloo IA
# 250 16th ave sw cedar rapids IA
# 1725  74th st west des moines IA
# 1703 mt pleasant st burlington IA
# 2401 a chamberlain st ames IA
# 1220 west main manchester IA
# 919 hwy 1 west iowa city IA
# 6981 ne 14th st ankeny IA
# 130 s roosevelt ave burlington IA
# 118 south main st. holstein IA
# 617 sycamore waterloo IA
# 225 edgewood rd cedar rapids IA
# 300 iowa speedway dr newton IA
# 769 prospect st sw le mars IA
# 110  s  d  st oskaloosa IA
# 200 susan lawrence dr ida grove IA
# 1116, hwy 69 south forest city IA
# 1604 bent bedford IA
# 5405 mills civic pkwy west des moines IA
# 1004 main st rock valley IA
# 1621 university ave des moines IA
# 1131, market st gowrie IA
# 1207 n elm st jefferson IA
# 108  2nd st schleswig IA
# 1800  35th st west des moines IA
# 630 sw  9th st des moines IA
# 829 shakespeare ave stratford IA
# 315 s gilbert st iowa city IA
# 400 north delaware ave mason city IA
# 703 w pleasant st knoxville IA
# 619 burnett ave ames IA
# 2217 college cedar falls IA
# 1601 washington st davenport IA
# 735, logan ave waterloo IA
# 615  2nd ave sheldon IA
# 1220, n cody rd le claire IA
# 509 e platt maquoketa IA
# 901 sw 63rd st des moines IA
# 1711 sunset dr norwalk IA
# 109 se oralabor rd ankeny IA
# 826 e river dr davenport IA
# 423 sharp st glenwood IA
# 400 s second bellevue IA
# 303, hwy 150 n west union IA
# 102  4th st north box 434 fairbank IA
# 107, n  mill st lake mills IA
# 109 s 5th st adair IA
# 1516, se  1st st des moines IA
# 1101, n  lake ave storm lake IA
# 2403 us hwy 18 inwood IA
# 1925 w broadway council bluffs IA
# 1800 elm st dubuque IA
# 416 cedar st muscatine IA
# 2790 7th avenue marion IA
# 2108 isaac newton dr ames IA
# 101 main st fort atkinson IA
# 20 wilson avenue west cedar rapids IA
# 9th st sw b waukon IA
# 3501 w broadway st council bluffs IA
# 201 s front st montezuma IA
# 5120 ne 14th street des moines IA
# 1850 logan ave waterloo IA
# 2221 e euclid ave des moines IA
# 2604 w locust st davenport IA
# 5440 nw  86th st johnston IA
# 2203 a avenue west oskaloosa IA
# 1300  50th st west des moines IA
# 10  3rd st nw hartley IA
# 2150 east 1st st grimes IA
# 1007 s fremont st shenandoah IA
# 3941 se 14th st des moines IA
# 105, e jackson st corydon IA
# 1500 north jefferson indianola IA
# 12753 university ave clive IA
# 620 se 8th st altoona IA
# 100, cherry st allison IA
# 4218 morningside ave sioux city IA
# 719, n federal ave mason city IA
# 2001 blairs ferry road ne cedar rapids IA
# 3700 hubbell ave des moines IA
# 1303 north federal mason city IA
# 480 7th ave marion IA
# 101 8th st sw altoona IA
# 3800 belmont rd bettendorf IA
# 157 locust st dubuque IA
# 828, w river dr davenport IA
# 7229 university ave windsor heights IA
# 512 e oskaloosa pella IA
# 1712 s center  st marshalltown IA
# 1691 asbury road dubuque IA
# 118, s main st sigourney IA
# 1312 harrison st davenport IA
# 911 central ave hawarden IA
# 850 army post rd des moines IA
# 551 s illinois ave mason city IA
# 300 central ave w clarion IA
# 207 e locust st bloomfield IA
# 1400 3rd ave se independence IA
# 1554 broad st story city IA
# 1520 6th st sw cedar rapids IA
# 3501  8th st sw altoona IA
# 777  11th ave sw waukon IA
# 4649 hwy 13 central city IA
# 1207  12th ave se dyersville IA
# 611 main st dumont IA
# 201, e washington st mount pleasant IA
# 507 1st ave #100 rock rapids IA
# 109 east marion st manchester IA
# 2900 heartland dr coralville IA
# 3245 agency st burlington IA
# 214 n magnolia dr cedar falls IA
# 1515 se marshall st boone IA
# 1309, lafayette st waterloo IA
# 924 locust st glenwood IA
# 217 e broadway keota IA
# 530 north ave norwalk IA
# 2701 w burlington ave fairfield IA
# 1700 e washington mount pleasant IA
# 1119 market st. box 71 gowrie IA
# 301 annex rd madrid IA
# 1013 main keokuk IA
# 5970 morning star ct pleasant hill IA
# 1511 2nd ave north fort dodge IA
# 502, e ave nw cedar rapids IA
# 808 s main st monona IA
# 620 w bremer ave waverly IA
# 306, 1st st sw farley IA
# 525 brandilynn blvd cedar falls IA
# 2200 river road council bluffs IA
# 4860 nw urbandale dr urbandale IA
# 102 second st coralville IA
# 115 plymouth st ne le mars IA
# 727, se  14th st des moines IA
# 600 highway 12 south akron IA
# 806 w main st le grand IA
# 4040 war eagle dr sioux city IA
# 104 se  a st melcher-dallas IA
# 5655 c st sw cedar rapids IA
# 145 us hwy 18 w garner IA
# 607 s division st stuart IA
# 205 nw  1st st eagle grove IA
# 1745 madison ave council bluffs IA
# 858 middle rd bettendorf IA
# 1608 4th ave s denison IA
# 520 so fremont shenandoah IA
# 802 south center marshalltown IA
# 3804 hubbell ave des moines IA
# 4518 mortenson rd ste 109 ames IA
# 111 n wapello mediapolis IA
# 3151 se 14th st des moines IA
# 800 ford lane center point IA
# 215 s main st osceola IA
# 1532, ellis blvd nw cedar rapids IA
# 2424 sw 9th st des moines IA
# 103, n  main st baxter IA
# 112 s elm st cresco IA
# 3594 lafayette st evansdale IA
# 2545 e euclid ave des moines IA
# 104 highway 30 west toledo IA
# 517 2nd st coralville IA
# 30 four oaks dr sw cedar rapids IA
# 200 e oak st red oak IA
# 1300 n. second cherokee IA
# 4575 nw 2nd des moines IA
# 219 main st columbus junction IA
# 1219 1st st perry IA
# 303 w broadway st polk city IA
# 1620  4th ave, south denison IA
# 618 durant st harlan IA
# 415 industrial ave grinnell IA
# 68 monroe st floyd IA
# 2091 e main st lamoni IA
# 2825 gordon dr sioux city IA
# 300  4th st la porte city IA
# 215 s evans rd evansdale IA
# 40  w san marnan waterloo IA
# 1334 flammang dr waterloo IA
# 1459, ansborough ave waterloo IA
# 801 hull st corning IA
# 117 iowa ave dunlap IA
# 101 e ia highway 92 bevington IA
# 205 franklin st waterloo IA
# 923 w 7th st sioux city IA
# 3501 ep true pkwy west des moines IA
# 2727 dodge st dubuque IA
# 222 w front st buffalo IA
# 1045 n grand ave mount pleasant IA
# 2704 vine st west des moines IA
# 320, n  4th st clinton IA
# 1831 lake ave nw storm lake IA
# 707, palean st keokuk IA
# 4600 86th st urbandale IA
# 320 west street south grinnell IA
# 621 hwy 71 sioux rapids IA
# 1003 summer st burlington IA
# 2050 ia highway 38 tipton IA
# 2510 sw state st ankeny IA
# 22 s van buren st iowa city IA
# 306 washington story city IA
# 2905 w  1st st ankeny IA
# 777 main st emmetsburg IA
# 310 second st po box 249 gladbrook IA
# 802 cypress st muscatine IA
# 705 s fremont shenandoah IA
# 1801 valley view dr council bluffs IA
# 411 w 18th spencer IA
# 4201, center point rd ne cedar rapids IA
# 200 se laurel st waukee IA
# 500, hwy 175 ida grove IA
# 3619 stange rd ames IA
# 2485 hwy 92 washington IA
# 210, jones st le claire IA
# 5830 se 14th st des moines IA
# 1556 first avenue ne cedar rapids IA
# 408 6th ave durant IA
# 1607 north broadway red oak IA
# 2002 spruce hills dr bettendorf IA
# 122 a east front st brooklyn IA
# 711 gordon dr sioux city IA
# 1119 river forest rd evansdale IA
# 104 e eighth st spencer IA
# 708  13th st belle plaine IA
# 3845 elmore ave. davenport IA
# 4116 center pointe rd cedar rapids IA
# 425 gilbert st iowa city IA
# 1010  60th st west des moines IA
# 303 se 30th st des moines IA
# 709 first st w independence IA
# 3625 edgewood rd sw cedar rapids IA
# 3030 university ave des moines IA
# 9915 douglas ave urbandale IA
# 23828 hwy j18 moravia IA
# 5169 merle hay rd johnston IA
# 420 second st traer IA
# 3107, brady st davenport IA
# 620, meade dr north liberty IA
# 5358 hwy 64 baldwin IA
# 1001 1st ave sw cedar rapids IA
# 615 westwood dr   p.o box 96 north liberty IA
# 5901 fleur dr des moines IA
# 840, e le claire rd eldridge IA
# 1500, 1st  ave ne cedar rapids IA
# 1300 nicolaus st wilton IA
# 1304 main st w sac city IA
# 802 e 1st st ankeny IA
# 1714 e kimberly rd davenport IA
# 601, main st cedar falls IA
# 1812 osborn st burlington IA
# 1310 w sheridan ave shenandoah IA
# 2260 john f kennedy rd dubuque IA
# 206 2nd ave ne west bend IA
# 1108 central ave estherville IA
# 600 sheldon creston IA
# 102 west anson st marshalltown IA
# 923 n  1st st winterset IA
# 1311 4 street sw waverly IA
# 2324 n 15th st fort dodge IA
# 2127 m l king jr pkwy des moines IA
# 1420 mt vernon rd cedar rapids IA
# 2050 john f kennedy rd dubuque IA
# 8450 meredith dr urbandale IA
# 1201 1/2 lakeshore dr storm lake IA
# 103, blair st kellogg IA
# 111 s phillips st algona IA
# 90 10th st s northwood IA
# 201 n fillmore st mount ayr IA
# 202, s main st new sharon IA
# 1301 eagle ridge rd le claire IA
# 109 n 4th st montezuma IA
# 213 s main st clarksville IA
# 301 main st jewell junction IA
# 121 north clinton albia IA
# 101, w main st anthon IA
# 111 main st keosauqua IA
# 105 w monroe st pleasantville IA
# 901 n ankeny blvd ankeny IA
# 2400 college dr osceola IA
# 625 pacha parkway north liberty IA
# 214 viking plaza dr cedar falls IA
# 1005 s county line rd toledo IA
# 302 west walnut st ogden IA
# 7 goethe street  suite b guttenberg IA
# 110 e main st wesley IA
# 3301 j st cedar rapids IA
# 303, college dr decorah IA
# 1864 hwy 141 sloan IA
# 101 village dr tiffin IA
# 14562 washington rd west burlington IA
# 1101 s 5th st polk city IA
# 2765 commerce dr iowa city IA
# 1724 5th  ave s fort dodge IA
# 512 river ave n belmond IA
# 504, g ave grundy center IA
# 3527 spring st davenport IA
# 504 south highway oakland IA
# 955 morman trek blvd iowa city IA
# 1530 north 2nd st clinton IA
# 196 s 50th st west des moines IA
# 1307 n second clinton IA
# 29356 298th st neola IA
# 609, s main st charles city IA
# 576, n main ave britt IA
# 1450, loras blvd dubuque IA
# 814 w bell ave knoxville IA
# 1100 eagle view dr marion IA
# 205 brown st oakland IA
# 129 center st wall lake IA
# 1208  4th st ne hampton IA
# 2992 sunset dr norwalk IA
# 1610 rockingham rd davenport IA
# 1132 hwy  69 south forest city IA
# 136  1st st west des moines IA
# 58231 190th st pacific junction IA
# 1022 skylar st denver IA
# 2757 charles city rd nashua IA
# 2255 john f kennedy rd dubuque IA
# 2601 se creekview dr ankeny IA
# 2406 main st emmetsburg IA
# 200, e 3rd st west liberty IA
# 6027 university ave ste 100 cedar falls IA
# 2715 south 25th st clinton IA
# 3000 se 22nd st des moines IA
# 15600 hickman rd clive IA
# 500, north ave norwalk IA
# 902 1st ave n fort dodge IA
# 701 mormon trek blvd iowa city IA
# 527 park ave story city IA
# 404, locust st lohrville IA
# 202, w 4th ave swea city IA
# 1021 n 1st st winterset IA
# 4801 ne 14th st des moines IA
# 3105 hudson rd cedar falls IA
# 1725 nw 86th st clive IA
# 107 e traer greene IA
# 1314  7th st jesup IA
# 2910  1 ave s fort dodge IA
# 302 enterprise dr sw independence IA
# 701 main st malvern IA
# 201 s 4th st farmington IA
# 1701 railroad st ruthven IA
# 220 w bremer ave waverly IA
# 107 1st st sw elkader IA
# 5427 center point rd ne cedar rapids IA
# 3184 highway 22 riverside IA
# 1224 n federal ave mason city IA
# 55 john f kennedy rd dubuque IA
# 20611 hwy 1 n keosauqua IA
# 2001 w 2nd ave indianola IA
# 201 s main st hazleton IA
# 101 west madison edgewood IA
# 1100, e 5th st storm lake IA
# 704 w 7th st po box 372 atlantic IA
# 3015 grand ave ames IA
# 1290 hwy 18 everly IA
# 1920 s federal ave mason city IA
# 125 6th st ames IA
# 2110 guthrie ave des moines IA
# 311  3rd ave w oskaloosa IA
# 304 w. madison washington IA
# 107 ia hwy 60 hospers IA
# 1800 n 16th st council bluffs IA
# 1581 1st ave se cedar rapids IA
# 228 n hwy 71 arnold's park IA
# 508 n elm jefferson IA
# 1026 main grinnell IA
# 1805 brady st davenport IA
# 2834 ansborough ave waterloo IA
# 4607 n pine st davenport IA
# 3221 manawa centre dr council bluffs IA
# 813 n lincoln ste 1 knoxville IA
# 2405, n broadway st red oak IA
# 106 n front st montezuma IA
# 2580, naples ave iowa city IA
# 1020 gateway dr carlisle IA
# 1008 laporte rd waterloo IA
# 4523, morningside ave sioux city IA
# 2501, floyd blvd sioux city IA
# 3645 stone creek circle sw cedar rapids IA
# 8600 meredith dr urbandale IA
# 430 s 35th st council bluffs IA
# 12041 douglas pkwy urbandale IA
# 2711 mt vernon rd cedar rapids IA
# 1372 e 14th st des moines IA
# 2844 university ave waterloo IA
# 1131, s hwy 52 guttenberg IA
# 3535 marigold dr waterloo IA
# 709 monterey dr carroll IA
# 103 walnut st. e columbus junction IA
# 9 waterhouse ave central city IA
# 206 short st mechanicsville IA
# 633 chase st osage IA
# 14151 wabash ave council bluffs IA
# 2611 pierce st sioux city IA
# 6630 mills civic parkway west des moines IA
# 25 w burlington st iowa city IA
# 210 maple st box 295 hubbard IA
# 1655 w kimberly rd davenport IA
# 105 e 6th st carroll IA
# 465 hwy 965 unit g north liberty IA
# 403 stephens st tiffin IA
# 1203 blairs ferry rd marion IA
# 4600 merle hay rd urbandale IA
# 1325 albia rd ottumwa IA
# 119 n main st po box 296 conrad IA
# 1006, n columbus st west liberty IA
# 902 n hwy 69 huxley IA
# 303 n cody rd le claire IA
# 104 e euclid ave des moines IA
# 421 n main st burlington IA
# 115 south 29th st fort dodge IA
# 410 w main st laurens IA
# 101 main st kingsley IA
# 111 3rd st sioux city IA
# 535 e broadway council bluffs IA
# 648 n  marquette st davenport IA
# 1330 e university ave des moines IA
# 1711 hawkeye dr boone IA
# 115  1st ave nw sioux center IA
# 1925 s lakeport st sioux city IA
# 731 seneca st storm lake IA
# 2802 s center st marshalltown IA
# 4960 e broadway ave des moines IA
# 215, s rerick ave primghar IA
# 4003 peru rd dubuque IA
# 309 n locust st glenwood IA
# 111 e harrison st jefferson IA
# 1200 s 16th st clarinda IA
# 919 w 5th st waterloo IA
# 680 lindale dr marion IA
# 726 creek top council bluffs IA
# 211, w 53rd st davenport IA
# 2335 university ave dubuque IA
# 4307 w locust st davenport IA
# 255 16th st sw sioux center IA
# 504, e burlington st iowa city IA
# 1301, main st keokuk IA
# 2719 grand ave ames IA
# one prairie meadows drive altoona IA
# 120 e main st state center IA
# 1999 grand ave west des moines IA
# 712 s oak st inwood IA
# 104 north fillmore mount ayr IA
# 1918 se 14th st des moines IA
# 1900, summer st burlington IA
# 910 main st arlington IA
# 101 hwy 7 fonda IA
# 510 c ave denison IA
# 730, high st rockwell city IA
# 1910  23rd st harlan IA
# 301 poplar st atlantic IA
# 200 hwy 151 e walford IA
# 327 5th st west point IA
# 102 w hwy 30 wheatland IA
# 105 w sherman po bx 1023 monroe IA
# 1215 main st keokuk IA
# 900 s locust st glenwood IA
# 109, wapello st mediapolis IA
# 840 s oak iowa falls IA
# 3200 se 14th st des moines IA
# 3349 mt vernon rd se cedar rapids IA
# 22 north main dayton IA
# 210 north hwy otho IA
# 601 e main panora IA
# 1293 8th ave west des moines IA
# 2323 main st cedar falls IA
# 5340 16th ave sw cedar rapids IA
# 1615 bishop ave waterloo IA
# 501 n douglas st afton IA
# 3450  4th st sw mason city IA
# 101 1st st ne buffalo center IA
# 403, chestnut st harpers ferry IA
# 920 lawrence dr burlington IA
# 123 n lawler st postville IA
# 900 locust st scranton IA
# 1225 7th ave marion IA
# 1032 state st bettendorf IA
# 1030, veteran memorial hwy council bluffs IA
# 1201 n jefferson indianola IA
# 719 w hwy 92 winterset IA
# 801 n 1st st grimes IA
# 4024 fleur dr des moines IA
# 1100 s 3rd st polk city IA
# 821 broadway st waterloo IA
# 1923, 5th  ave  s fort dodge IA
# 312 w washington st exira IA
# 6990 douglas ave urbandale IA
# 208 main st manson IA
# 113 w vanburen centerville IA
# 112 river ave s belmond IA
# 2810, willis ave perry IA
# 911 hwy 69 huxley IA
# 403 e 6th logan IA
# 4555 fleur dr des moines IA
# 901, e washington st mount pleasant IA
# 5225 nw  86th  st johnston IA
# 4103 floyd blvd sioux city IA
# 516, highway 141 coon rapids IA
# 100 pierce st sioux city IA
# 205 nw elm st corwith IA
# 301 hwy. 34 west albia IA
# 1200 n walnut st colfax IA
# 350 se university ave waukee IA
# 3108 west central park ave #2 davenport IA
# 110 n hwy 218 st ansgar IA
# 204, e south st manly IA
# 655, robbins rd hiawatha IA
# 2425, whitetail dr cedar falls IA
# 975 n chestnut ave earlham IA
# 606 grundy ave reinbeck IA
# 503 hwy 61 south wapello IA
# 5901 douglas ave des moines IA
# 705 idaho st glidden IA
# 319, court st rockwell city IA
# 1231  1st ave s fort dodge IA
# 10151 university ave clive IA
# 1635 west 53rd st davenport IA
# 1104 washington st waterloo IA
# 101 8th st se altoona IA
# 1102 2nd st webster city IA
# 3221, center point rd ne cedar rapids IA
# 165 sw magazine rd ankeny IA
# 18820, bellevue cascade rd zwingle IA
# 110, s  akir  st latimer IA
# 3500, ave a council bluffs IA
# 702 us hwy 65 colo IA
# 24687 hwy 13 n elkader IA
# 332, e  2nd st davenport IA
# 6130 nw 86th st johnston IA
# 301 water st cambridge IA
# 1200 s market st solon IA
# 128 w mission strawberry point IA
# 2601, williams blvd sw cedar rapids IA
# 5 e anson marshalltown IA
# 930 commercial st lisbon IA
# 613, n 3rd ave marshalltown IA
# 6200 se 14th st des moines IA
# 2177 m ave williamsburg IA
# 104 e first st ankeny IA
# 400 prairie bluff dr waukee IA
# 333 e grand ave des moines IA
# 5b  lincoln ave eldridge IA
# 2751 heartland dr coralville IA
# 2245, us hwy 71 early IA
# 820 e main st lake city IA
# 101 w 7th st sanborn IA
# 100, pearl st aurelia IA
# 3715 state st bettendorf IA
# 103 e carlisle maquoketa IA
# 1111 ia highway 175 ellsworth IA
# 830 middle rd bettendorf IA
# 2530 westwinds dr iowa city IA
# 1777 division st davenport IA
# 3501 ingersoll ave des moines IA
# 1660 w locust st davenport IA
# 209 s union st rock rapids IA
# 3717 1st ave se cedar rapids IA
# 8228 douglas ave urbandale IA
# 14628, mile hill lane dubuque IA
# 201, market st lake park IA
# 311 north jefferson indianola IA
# 1415 grand falls blvd larchwood IA
# 402 north main st clarksville IA
# 102 s water ave new hampton IA
# 526 main st ackley IA
# 215 e euclid ave des moines IA
# 354, e eldora rd hudson IA
# 1531 2nd ave council bluffs IA
# 301 north marion ave washington IA
# 235 edgewood rd ne cedar rapids IA
# 1308 s lincoln st knoxville IA
# 207 e main st belmond IA
# 2801 e 13th st ames IA
# 1904, mt vernon rd se cedar rapids IA
# 2722 ne 120th st swisher IA
# 308, w mission strawberry point IA
# 320 w bremer ave waverly IA
# 4506 lincoln way ames IA
# 1101 2nd st coralville IA
# 1127 story boone IA
# 500 iowa st iowa falls IA
# 401 nw church st leon IA
# 2603 park st sheldon IA
# 315 story st boone IA
# 310 mckenzie ave council bluffs IA
# 136 lincoln hwy nevada IA
# 206 n main st traer IA
# 1501 e san marnan waterloo IA
# 210  11th st charles city IA
# 11989 hickman rd urbandale IA
# 303 us hwy 61 n wapello IA
# 6200 merle hay rd johnston IA
# 305 crisman st dysart IA
# 300 e blairs ferry rd hiawatha IA
# 106 w mains st po box 142 st lucas IA
# 620 s downey st west branch IA
# 1205/1207, locust st. davenport IA
# 201 s central ave burlington IA
# 721 main st tabor IA
# 6417 northglen dr johnston IA
# 1660 22nd st west des moines IA
# 4685, nw  2nd st des moines IA
# 1759 madison ave council bluffs IA
# 1819 beaver ave des moines IA
# 101 n lake st lake mills IA
# 100 w main st fredericksburg IA
# 1447  2nd st webster city IA
# 4349 cumming ave. cumming IA
# 4267 sergeant rd sioux city IA
# 305 34th ave nw altoona IA
# 102, albany ave ne orange city IA
# 605 6th st s springville IA
# 1661 32nd st ne cedar rapids IA
# 4028 ne 14th st des moines IA
# 1004 w 1st st leon IA
# 324 edgewood rd nw cedar rapids IA
# 2699 rockdale dubuque IA
# 595 n kansas ave north liberty IA
# 629 s division st stuart IA
# 101 commercial st raymond IA
# 12633 resort dr moravia IA
# 801 university ave des moines IA
# 117 e san marnan dr waterloo IA
# 706, 10th st onawa IA
# 650 w hickman rd waukee IA
# 1116 e nevada st marshalltown IA
# 2402, 17th st spirit lake IA
# 309, center ave mitchellville IA
# 502, 3rd  st delhi IA
# 15 north 16th st council bluffs IA
# 3414 8th st sw altoona IA
# 515 w water st fayette IA
# 832 broadway st larchwood IA
# 903 n sumner ave creston IA
# 534 church st ottumwa IA
# 419 merrill st bussey IA
# 205, 4th st eldon IA
# 510, 23rd ave council bluffs IA
# 121 walnut eddyville IA
# 1825 n ankeny blvd ankeny IA
# 307, s 4th ave armstrong IA
# 1204 1st st palo IA
# 2721 dows williams rd dows IA
# 701 poplar st atlantic IA
# 709 grandview ave muscatine IA
# 114 n main st osceola IA
# 120 n main st george IA
# 1205 curtis br rd ne shueyville IA
# 1928, sherwood dr council bluffs IA
# 327 w 4th st ottumwa IA
# 800 hamilton blvd sioux city IA
# 1101, jefferson st denver IA
# 200, n walnut st lenox IA
# 719 2nd ave w spencer IA
# 110 south main sigourney IA
# 1108 w agency rd west burlington IA
# 305 us 34 business danville IA
# 109 5th st sibley IA
# 4920, johnson ave nw cedar rapids IA
# 100 grant st elma IA
# 550 wilson ave sw cedar rapids IA
# 2293, hwy 30 grand mound IA
# 1850 22nd st west des moines IA
# 609 central ave w hampton IA
# 500 w main st seymour IA
# 6301, se 116th st runnells IA
# 320 s duff ames IA
# 201, 8th ave se cedar rapids IA
# 14201 hickman rd urbandale IA
# 1201, e main st knoxville IA
# 731 s riverside dr iowa city IA
# 3500 dodge st dubuque IA
# 1006 w pleasant st pleasantville IA
# 1601 w burlington ave fairfield IA
# 3902, state st bettendorf IA
# 107 w taylor st creston IA
# 320, w mamie eisenhower ave boone IA
# 4400 128th st urbandale IA
# 110 w cedar st marcus IA
# 502, main dakota city IA
# 545 w washington st council bluffs IA
# 1803 superior st webster city IA
# 3419 16th ave sw cedar rapids IA
# 3215 7th ave marion IA
# 1006, chatburn ave harlan IA
# 1211 washington st hamburg IA
# 2418 stewart rd muscatine IA
# 110, locust st atlantic IA
# 1453 co hwy g76 new virginia IA
# 115 n 22nd st fort dodge IA
# 106, w 2nd st brooklyn IA
# 19900 virginia hills rd council bluffs IA
# 833, 42nd st des moines IA
# 641 edgewood rd nw cedar rapids IA
# 325 central ave w clarion IA
# 3325 16th ave sw cedar rapids IA
# 2010 washington st pella IA
# 701, s  frederick  ave oelwein IA
# 1976 franklin st waterloo IA
# 102 w main st treynor IA
# 1904 broadway st iowa city IA
# 315, s main st inwood IA
# 2805 telegraph rd davenport IA
# 2639 avenue l fort madison IA
# 2520 gordon dr sioux city IA
# 1, grove rd eldridge IA
# 1906 keokuk spirit lake IA
# 1101 rhomberg ave dubuque IA
# 2930 e university ave des moines IA
# 2503 5th ave s fort dodge IA
# 3434 1st ave ne cedar rapids IA
# 135 madison st winthrop IA
# 309 central ave west hampton IA
# 107, w  7th st logan IA
# 2303 merle hay rd des moines IA
# 1001 sanborn ave okoboji IA
# 15601 hickman rd clive IA
# 1800 south b ave nevada IA
# 604 w 2nd ida grove IA
# 812 flindt dr storm lake IA
# 4200, lewis access rd center point IA
# 318, e 2nd st. davenport IA
# 409 e center conrad IA
# 560, 33rd ave sw cedar rapids IA
# 2824, 1st ave ne cedar rapids IA
# 1495 state st ely IA
# 609 arrowhead dr denison IA
# 2024 5th ave council bluffs IA
# 200 6th ave slater IA
# 3804 metro dr council bluffs IA
# 154 bennett ave council bluffs IA
# 2425 muscatine ave iowa city IA
# 100, main st maxwell IA
# 1709 antique city dr walnut IA
# 302 hwy 136 lost nation IA
# 942  2nd st webster city IA
# 304 4th st fontanelle IA
# 1303 4th st sw mason city IA
# 1900 hamilton blvd sioux city IA
# 205 west bluff st cherokee IA
# 1601 fifth avenue s fort dodge IA
# 315 main st ireton IA
# 400 market st audubon IA
# 33280 335th st minden IA
# 1200 cedar cross rd dubuque IA
# 916 e main st marshalltown IA
# 4804, hwy  61 south muscatine IA
# 306, n main allison IA
# 207 front st humeston IA
# 132 north main st po box 306 paullina IA
# 209 e main st st charles IA
# 1615, central ave estherville IA
# 1120 s commercial eagle grove IA
# 3340 jfk  rd dubuque IA
# 502 market delmar IA
# 2026 riverside blvd sioux city IA
# 1659d marshalltown blvd melbourne IA
# 23226 centre dr glenwood IA
# 2332, falls ave waterloo IA
# 2702 se delaware ave ankeny IA
# 308 n washington wellsburg IA
# 105 se first st gilmore city IA
# 72, n okoboji grove rd arnold's park IA
# 111 w ridgeway ave waterloo IA
# 1441 marak rd nw swisher IA
# 201 sunset st urbana IA
# 1019 n chestnut st avoca IA
# 101 first st merrill IA
# 202 west southern st sutherland IA
# 216, 3rd st se cedar rapids IA
# 105 se nixon st cascade IA
# 2029 5th ave south fort dodge IA
# 1002 west st grinnell IA
# 100, n  5th st guthrie center IA
# 101 e  hwy 7 alta IA
# 302, se 6th st greenfield IA
# 2905 fourth ave clear lake IA
# 1749 w broadway council bluffs IA
# 1001 3rd  st victor IA
# 111 w main st. riceville IA
# 2150 twin valley dr dubuque IA
# 1215 e 16th st dubuque IA
# 2360 central dubuque IA
# 412, garfield st rolfe IA
# 1525 e kimberly davenport IA
# 3434 nebraska ave council bluffs IA
# 800 lake ave storm lake IA
# 500 hwy 67 n princeton IA
# 1002 w 2nd st prairie city IA
# 111, mormon bridge rd crescent IA
# 323 e burlington st iowa city IA
# 1704 s story st boone IA
# 911 3rd  ave sw state center IA
# 205 2nd st coralville IA
# 3505 n  ankeny blvd ankeny IA
# 2420 lincoln way ames IA
# 4011 e 53rd st davenport IA
# 401, s  4th  st mapleton IA
# 5308 university ave west des moines IA
# 310 story st boone IA
# 1203, tri view ave sioux city IA
# 111, main st montrose IA
# 2135 se delaware ave ankeny IA
# 401 grant st walker IA
# 2509 whitetail dr cedar falls IA
# 1802, sycamore st granger IA
# 4900 mills civic pkwy west des moines IA
# 3140 se 14th st des moines IA
# 3132 1st ave ne cedar rapids IA
# 14 e congress nora springs IA
# 901, 3rd  st victor IA
# 5002 avenue o fort madison IA
# 1720 w kimberly rd davenport IA
# 1303 se marshall st boone IA
# 3425 middle rd bettendorf IA
# 102, e  bradford st west union IA
# 6175 50th ave norwalk IA
# 802, s riverview bellevue IA
# 2604 16th ave cedar rapids IA
# 1251 4th st sw mason city IA
# 520 w main st laurens IA
# 700 debra dr van meter IA
# 911 sw 7th st atlantic IA
# 4100 university ave west des moines IA
# 501 mcpherson st casey IA
# 912 main st anita IA
# 222, central ave clarion IA
# 3539 lafayette rd evansdale IA
# 2122 main st keokuk IA
# 111 n 3rd ave marshalltown IA
# 1204 1st ave east newton IA
# 102, w veterans dr ogden IA
# 805 grand ave s spencer IA
# 807 1st st sully IA
# 1000 n jefferson st indianola IA
# 1210 e 16th st dubuque IA
# 1005 gordon dr sioux city IA
# 2821 1st ave se cedar rapids IA
# 990, robins square dr robins IA
# 1807 hwy 5 s lovilia IA
# 115, 25th  ave gilbertville IA
# 4650 morningside ave sioux city IA
# 3105 grand prairie pkwy waukee IA
# 2303 muscatine ave iowa city IA
# 110, e jefferson st delaware IA
# 188, parkridge rd atkins IA
# 717 1st  ave cascade IA
# 1012 maple st burlington IA
# 1905 n  2nd st clinton IA
# 615, s  downey st west branch IA
# 1104 n riverview st bellevue IA
# 2107 agency st burlington IA
# 4200 s york st sioux city IA
# 5750 c ave ne cedar rapids IA
# 12633 resort drive moravia IA
# 236 peosta st peosta IA
# 2214 muscatine ave iowa city IA
# 106, e  erie st missouri valley IA
# 901 s market st oskaloosa IA
# 7305 laporte rd washburn IA
# 201 madison ave donnellson IA
# 504 16th st n grand junction IA
# 1008, grand alden IA
# 816 greene st adel IA
# 2307, lucas street muscatine IA
# 2881, highway 61 muscatine IA
# 2130, court ave chariton IA
# 1118, highway 30 stanwood IA
# 4305 w mt pleasant west burlington IA
# 110 s 5th st adair IA
# 2508 n court st ottumwa IA
# 510 okoboji ave milford IA
# 301 w bennett ave council bluffs IA
# 2320, 15th street fort dodge IA
# 135, madison street winthrop IA
# 3910 university ave waterloo IA
# 414 clark street pella IA
# 2301 s 24th st council bluffs IA
# 3232 utica ridge rd. bettendorf IA
# 5101, 230th street albert city IA
# 800 grand ave spencer IA
# 904 washington ave iowa falls IA
# 806 s  4th st clinton IA
# 1072, cedar cross rd dubuque IA
# 100 w mclane st osceola IA
# 4901 86th st urbandale IA
# 720 hwy 71 sioux rapids IA
# 406 e main st lamoni IA
# 1220 n cody rd le claire IA
# 122, front st. brooklyn IA
# 90 w. kimberly rd ste 55-56 davenport IA
# 2715 iowa ave onawa IA
# 108 e college st iowa city IA
# 1200 w 18th st s newton IA
# 1308 a ave e oskaloosa IA
# 2324 transit plaza sioux city IA
# 2000 wiley blvd sw ste 106 cedar rapids IA
# 3445, county home rd robins IA
# 101 main st kingsley IA
# 2200, river road, gift shop council bluffs IA
# 290, hwy 28 martensdale IA
# 1305 e south street mount ayr IA
# 1001 grand ave spencer IA
# 1920 federal ave s mason city IA
# 1839, madison ave council bluffs IA
# 950, west view dr rock valley IA
# 3100 se grimes blvd. ste 100 grimes IA
# 814, c ave vinton IA
# 1102 2nd st webster city IA
# 630, 6th ave dewitt IA
# 117 san marnan dr e waterloo IA
# 616 halland ave stanton IA
# 509 s 3rd ave villisca IA
# 108, college iowa city IA
# 300 central ave w clarion IA
# 2175 central avenue dubuque IA
# 1224 federal ave n mason city IA
# 411 13th street humboldt IA
# 200, green street muscatine IA
# 406, east st shelby IA
# 228, n hwy 71 arnold's park IA
# 126a welch ave ames IA
# 2515 dean avenue des moines IA
# 3330 16th avenue cedar rapids IA
# 1803 superior st webster city IA
# 534 church st ottumwa IA
# 115 22nd st n fort dodge IA
# 1119 river forest rd evansdale IA
# 3020 duff ave ames IA
# 109, locust st carter lake IA
# 1976 franklin st waterloo IA
# 1443 2nd ave des moines IA
# 112 river ave s belmond IA
# 1303 4th st sw mason city IA
# 527 park ave story city IA
# 210, hwy 20 sac city IA
# 105, main st alburnett IA
# 1601 5th ave fort dodge IA
# 405 1st ave e newton IA
# 1424 e euclid ave des moines IA
# 1290 s dubuque st north liberty IA
# 5050 nw 2nd ave des moines IA
# 200 e oak st red oak IA
# 117 w 1st st sumner IA
# 595 country ln north liberty IA
# 1430 1st ave north altoona IA
# 2508 court st n ottumwa IA
# 1455 grant street south bondurant IA
# 1419 1st ave n altoona IA
# 2839 east university ave. des moines IA
# 802 s riverview st bellevue IA
# 122 main st van horne IA
# 7 goethe street ste. b guttenberg IA
# 70 kirkwood court sw cedar rapids IA
# 306 washington story city IA
# 105 1st ave se oelwein IA
# 1203 5th st. sioux city IA
# 1031 west st grinnell IA
# 1802 w 7th st davenport IA
# 114 n center st. marshalltown IA
# 420 court ave des moines IA
# 2723 grand ave des moines IA
# 109 e 1st st. # b grimes IA
# 403 main st. coon rapids IA
# 1691 asbury rd dubuque IA
# 585 hwy 965 ste d & e north liberty IA
# 346 plymouth st sw le mars IA
# 3134 manawa center dr. # 9 council bluffs IA
# 4313 fleur dr des moines IA
# 425 s gilbert street iowa city IA
# 602 s highland williamsburg IA
# 617 42nd ave amana IA
# 1205 & 1207 e locust st davenport IA
# 1201 1st ave se cedar rapids IA
# 2728 center st. cedar falls IA
# 2547 2nd ave council bluffs IA
# 7690 hickman rd windsor heights IA
# 806 w main st le grand IA
# 300 east st arlington IA
# 721 central ave w hampton IA
# 300 east main cherokee IA
# 215 w 4th st st ansgar IA
# 502 e ave nw cedar rapids IA
# 1030 8th st boone IA
# 2013 central ave dubuque IA
# 3720 lincoln way ames IA
# 3540 w broadway council bluffs IA
# 228 n main st. monticello IA
# 515 broadway st waterloo IA
# 919 w 5th st waterloo IA
# 320 n 4th st clinton IA
# 315 fletcher ave waterloo IA
# 5427  center point rd cedar rapids IA
# 701 s frederick ave oelwein IA
# 209 e leclaire rd eldridge IA
# 2810 wills ave perry IA
# 1907 army post rd des moines IA
# 213 main st. doon IA
# 220 50th st west des moines IA
# 145 university ave des moines IA
# 3594 lafayette road evansdale IA
# 5901 mills civic pkwy #2000 west des moines IA
# 1309 lafayette st waterloo IA
# 8400 nicc drive peosta IA
# 1908 clark st charles city IA
# 700 w elm ave pocahontas IA
# 315 s gilbert st iowa city IA
# 11 n 3rd ave marshalltown IA
# 2704 vine st. west des moines IA
# 2424 sw 9th st #1 des moines IA
# 101 comerical street raymond IA
# 320 2nd st gladbrook IA
# 402 n main st clarksville IA
# 535, hill street dubuque IA
# 632 8th st. se orange city IA
# 818 hwy 105 northwood IA
# 215 w. milwaukee ave storm lake IA
# 101 8th st. n northwood IA
# 1810 state street bettendorf IA
# 2400 university blvd ames IA
# 1202 a ave e oskaloosa IA
# 3804 hubbell ave des moines IA
# 425 2nd st redfield IA
# 1004 main st. rock valley IA
# 1761 independence ave waterloo IA
# 101 main st fort atkinson IA
# 4506 lincoln way ames IA
# 800 hamilton blvd. sioux city IA
# 4335 texas st waterloo IA
# 3715 state st. bettendorf IA
# 320 5th st hudson IA
# 3108 w central park ave davenport IA
# 600 7th ave tripoli IA
# 4307 w locust st davenport IA
# 615 2nd ave sheldon IA
# 712 s oak st inwood IA
# 2920 w locust st davenport IA
# 1011 s frederick oelwein IA
# 103 hwy 31 washta IA
# 526 main st ackley IA
# 101 e ia hwy 92 bevington IA
# 395 western avenue marengo IA
# 1116 e nevada st marshalltown IA
# 1630 east 16th st dubuque IA
# 977 198th pl. pella IA
# 635 lang creek ave grinnell IA
# 107 n mill st lake mills IA
# 6005 merle hay road johnston IA
# 1225 fountains way cedar falls IA
# 113 hwy 30 west toledo IA
# 116 w water st ste d decorah IA
# 1203 n walnut colfax IA
# 1545 1st ave se cedar rapids IA
# 1833 elmwood rd earling IA
# 210 e. maple st hubbard IA
# 609 s main st charles city IA
# 720 east main lamoni IA
# 3345 270th ave keokuk IA
# 215 w main st. fredericksburg IA
# 716 s 4th st clinton IA
# 119 n. main st conrad IA
# 2102 lafayette st waterloo IA
# 211 highway 18 e. algona IA
# 412 garfield st rolfe IA
# 100 amherst blvd nashua IA
# 1021 east main street ottumwa IA
# 402 e main anamosa IA
# 1701 iowa ave e marshalltown IA
# 318 e north st. truro IA
# 801 e charles st oelwein IA
# 202 4th st north rockwell IA
# 132 n. main paullina IA
# 700 rhomberge ave dubuque IA
# 2798 commerce dr. coralville IA
# 2500 7th ave marion IA
# 2070 nw 100th st clive IA
# 114 mamie eisenhower boone IA
# 101 e mt. pleasant street west burlington IA
# 1402 9th st se dyersville IA
# 102 north main street kanawha IA
# 624 angular st. burlington IA
# 150 e. business 30 lisbon IA
# 2024 5th ave council bluffs IA
# 2100 jfk rd dubuque IA
# 209 east 3rd st templeton IA
# 710 s pine st new london IA
# 6175 50th ave norwalk IA
# 708 2nd ave se cresco IA
# 1820 avenue h fort madison IA
# 714 grandview ave muscatine IA
# 3285 crosspark rd coralville IA
# 107 hospers dr s hospers IA
# 17005 hwy 69 ames IA
# 136 lincoln hwy nevada IA
# 2411 2nd st ste 4 coralville IA
# 220 n augusta ave oxford IA
# 110 south main street sigourney IA
# 510 e hwy 30 carroll IA
# 1401 central ave dubuque IA
# 117 iowa ave dunlap IA
# 5120 ne 14th st des moines IA
# 588 boyson rd ne #110 cedar rapids IA
# 234 w 3rd st davenport IA
# 3070 hwy 22 e riverside IA
# 200 1st ave ne ste 124 cedar rapids IA
# 1610 rockingham rd davenport IA
# 1998 jackson st dubuque IA
# 100 s. front st. montezuma IA
# 1310 a ave west oskaloosa IA
# 1510 a isett ave muscatine IA
# 1133 s 22nd st fort dodge IA
# 870 ne alice's rd waukee IA
# 501 n brooks st lenox IA
# 212 west wood st. avoca IA
# 206 e 1st st grimes IA
# 201 s main st. albion IA
# 2177 m ave williamsburg IA
# 704 8th st se orange city IA
# 1345 2nd street south webster city IA
# 620 w tilden st postville IA
# 205 s main st new sharon IA
# 221 w marengo rd tiffin IA
# 4804 s highway 61 muscatine IA
# 3104 1st ave e newton IA
# 1207 state street tama IA
# 10 3rd st. nw, ste b hartley IA
# 1001 w main st lake city IA
# 401 college dr. decorah IA
# 111 wapello st n mediapolis IA
# 1107 13th ave n clinton IA
# 803 state st dexter IA
# 3731 hamilton blvd. sioux city IA
# 1310 s gilbert st iowa city IA
# 502 west erie st. missouri valley IA
# 404  11th st correctionville IA
# 1807 old stage rd. decorah IA
# 301 e trailridge ave indianola IA
# 120 e. main st. state center IA
# 2079 hwy 71 audubon IA
# 1101 main st manson IA
# 235 edgewood rd nw cedar rapids IA
# 118 south main street sigourney IA
# 9001 6th street sw cedar rapids IA
# 710 hwy 61 n wapello IA
# 720 richmond ave ottumwa IA
# 80 south st akron IA
# 154 bennett ave council bluffs IA
# 1026 w river drive davenport IA
# 1602 w 1st st ankeny IA
# 303 n cody road le claire IA
# 114 brick street bondurant IA
# 307 3rd st nw dayton IA
# 501 mcpherson st casey IA
# 1310 nw 18th st ankeny IA
# 2293 hwy 30 grand mound IA
# 2600 holiday rd coralville IA
# 108 iowa ave w marshalltown IA
# 1308 1st street perry IA
# 951 se gateway dr. grimes IA
# 205 nw elm st corwith IA
# 700 superior street webster city IA
# 1001 ave e hawarden IA
# 616 s. main st. monticello IA
# 627 s main st monticello IA
# 4021 fleur dr des moines IA
# 201 n locust winfield IA
# 1109 3rd ave alton IA
# 1105 blunt pkwy charles city IA
# 200 w union st edgewood IA
# 215 1st st kalona IA
# 505 hwy 65 s manly IA
# 1501 1st ave e cascade IA
# 117 e railroad st norway IA
# 501 front st. garwin IA
# 5050 northland ave ne cedar rapids IA
# 208 w main st riceville IA
# 525 s gear ave west burlington IA
# 4301 stone ave sioux city IA
# 1000 riverside blvd sioux city IA
# 1441 marak rd nw swisher IA
# 321 locust st nw blairstown IA
# 709 grandview ave muscatine IA
# 975 s 11th st marion IA
# 701 ellis blvd nw cedar rapids IA
# 888 vernon valley drive se cedar rapids IA
# 5555 edgewood rd ne cedar rapids IA
# 504 2nd ave sheldon IA
# 618 durant street harlan IA
# 814 e main st rockford IA
# 5350 31st ave urbana IA
# 303 us hwy 61 n wapello IA
# 319 court st rockwell city IA
# 129 center street wall lake IA
# 13410 ia hwy 78 wapello IA
# 309 main st. osage IA
# 33000 hwy 57 new hartford IA
# 1410 willow creek dr. iowa city IA
# 1413 n franklin st manchester IA
# 1905 se 37th street grimes IA
# 504 s main st north english IA
# 19203 bunge ave council bluffs IA
# 340 marion blvd marion IA
# ...
#  {'lat': 41.5332699, 'lng': -93.5973669},
#  {'lat': 41.9893789, 'lng': -91.65155360000001},
#  {'lat': 41.60065669999999, 'lng': -90.9121109},
#  {'lat': 41.0189175, 'lng': -95.23277639999999},
#  {'lat': 41.5507588, 'lng': -90.50332619999999},
#  {'lat': 41.7288481, 'lng': -92.44432669999999},
#  {'lat': 42.4900282, 'lng': -96.40118489999999},
#  {'lat': 42.4628236, 'lng': -92.29724879999999},
#  {'lat': 43.1455087, 'lng': -95.1427996},
#  {'lat': 41.8973772, 'lng': -92.2772741},
#  {'lat': 41.55936519999999, 'lng': -90.52418329999999},
#  {'lat': 42.0208423, 'lng': -91.6643789},
#  {'lat': 41.6666165, 'lng': -91.53035829999999},
#  {'lat': 41.5849176, 'lng': -93.79137709999999},
#  {'lat': 41.5852314, 'lng': -93.55798229999999},
#  {'lat': 42.4684899, 'lng': -91.9018529},
#  {'lat': 41.942336, 'lng': -91.7152239},
#  {'lat': 41.5999571, 'lng': -93.6584585},
#  {'lat': 41.6299662, 'lng': -93.7555313},
#  {'lat': 40.8926947, 'lng': -92.8342995},
#  {'lat': 41.6542623, 'lng': -93.6972318},
#  {'lat': 42.1937084, 'lng': -92.4682577},
#  {'lat': 41.5520732, 'lng': -90.5693379},
#  {'lat': 41.7524842, 'lng': -91.6082301},
#  {'lat': 42.0737349, 'lng': -90.8360414},
#  {'lat': 41.9721805, 'lng': -91.6844971},
#  {'lat': 41.739482, 'lng': -91.60809739999999},
#  {'lat': 41.5311405, 'lng': -93.64468099999999},
#  {'lat': 41.655019, 'lng': -90.5725538},
#  {'lat': 41.9884784, 'lng': -91.6522744},
#  {'lat': 41.5897758, 'lng': -91.03492039999999},
#  {'lat': 42.4230415, 'lng': -95.00008629999999},
#  {'lat': 41.73250240000001, 'lng': -93.5863115},
#  {'lat': 41.5573234, 'lng': -90.55096449999999},
#  {'lat': 42.5329276, 'lng': -92.44602599999999},
#  {'lat': 40.8261713, 'lng': -91.11218319999999},
#  {'lat': 40.7655714, 'lng': -95.3846713},
#  {'lat': 42.5114632, 'lng': -90.71990559999999},
#  {'lat': 42.9630526, 'lng': -94.4426097},
#  {'lat': 43.4014457, 'lng': -94.8301108},
#  {'lat': 41.0522662, 'lng': -94.3734771},
#  {'lat': 42.03742769999999, 'lng': -92.9146306},
#  {'lat': 41.3425705, 'lng': -94.01224429999999},
#  {'lat': 42.7119882, 'lng': -92.4735517},
#  {'lat': 42.5290823, 'lng': -94.1783646},
#  {'lat': 41.6140338, 'lng': -93.6456511},
#  {'lat': 41.9779085, 'lng': -91.65115519999999},
#  {'lat': 42.5074816, 'lng': -90.7192817},
#  {'lat': 41.6428378, 'lng': -93.7342264},
#  {'lat': 42.6352722, 'lng': -95.1856147},
#  {'lat': 41.7147459, 'lng': -92.9031047},
#  {'lat': 43.0683541, 'lng': -94.2265527},
#  {'lat': 43.4436873, 'lng': -93.21808879999999},
#  {'lat': 40.7158901, 'lng': -94.23918309999999},
#  {'lat': 41.46866000000001, 'lng': -92.6512884},
#  {'lat': 41.5882199, 'lng': -90.3600519},
#  {'lat': 41.5859218, 'lng': -92.52344889999999},
#  {'lat': 42.7833451, 'lng': -92.6673706},
#  {'lat': 42.3025925, 'lng': -93.6405831},
#  {'lat': 41.0286433, 'lng': -92.8087592},
#  {'lat': 42.388469, 'lng': -95.8685454},
#  {'lat': 40.729283, 'lng': -91.9628125},
#  {'lat': 41.38669549999999, 'lng': -93.2707267},
#  {'lat': 41.7391536, 'lng': -93.5991075},
#  {'lat': 41.0232317, 'lng': -93.80035240000001},
#  {'lat': 41.7527189, 'lng': -91.60673299999999},
#  {'lat': 42.48099550000001, 'lng': -92.4441915},
#  {'lat': 41.161608, 'lng': -93.60442189999999},
#  {'lat': 42.0387722, 'lng': -94.030952},
#  {'lat': 42.7830374, 'lng': -91.096206},
#  {'lat': 43.0882484, 'lng': -93.9910879},
#  {'lat': 41.9446805, 'lng': -91.66631439999999},
#  {'lat': 43.3075261, 'lng': -91.7973889},
#  {'lat': 42.2274456, 'lng': -96.2364539},
#  {'lat': 41.69665210000001, 'lng': -91.66604869999999},
#  {'lat': 40.8399003, 'lng': -91.20924099999999},
#  {'lat': 41.7638138, 'lng': -93.71855149999999},
#  {'lat': 41.629628, 'lng': -91.4817703},
#  {'lat': 42.5013123, 'lng': -94.17389440000001},
#  {'lat': 42.8501553, 'lng': -93.6161606},
#  {'lat': 42.361304, 'lng': -92.7702997},
#  {'lat': 41.5563167, 'lng': -90.5471658},
#  {'lat': 42.419902, 'lng': -94.147313},
#  {'lat': 41.6499385, 'lng': -91.57464399999999},
#  {'lat': 41.86218059999999, 'lng': -90.1839629},
#  {'lat': 41.5710311, 'lng': -93.77180369999999},
#  {'lat': 41.8588431, 'lng': -90.18418249999999},
#  {'lat': 41.4391119, 'lng': -95.61288049999999},
#  {'lat': 43.060949, 'lng': -92.68272089999999},
#  {'lat': 43.1018221, 'lng': -93.8023979},
#  {'lat': 42.5004904, 'lng': -90.68710899999999},
#  {'lat': 41.3047744, 'lng': -93.10600439999999},
#  {'lat': 42.0364361, 'lng': -91.5544444},
#  {'lat': 41.30481944444094, 'lng': -95.40007920462052},
#  {'lat': 42.2713165, 'lng': -95.09088369999999},
#  {'lat': 42.7530443, 'lng': -93.2028009},
#  {'lat': 41.4840603, 'lng': -93.674838},
#  {'lat': 41.52053739999999, 'lng': -90.5995111},
#  {'lat': 43.2624685, 'lng': -93.6371937},
#  {'lat': 41.5706435, 'lng': -93.7038714},
#  {'lat': 41.0419687, 'lng': -95.8216628},
#  {'lat': 42.6620588, 'lng': -92.336271},
#  {'lat': 42.9588979, 'lng': -92.5478274},
#  {'lat': 42.5111465, 'lng': -90.7216562},
#  {'lat': 41.7036381, 'lng': -93.5710873},
#  {'lat': 43.1127427, 'lng': -94.68303569999999},
#  {'lat': 41.569631, 'lng': -91.26158799999999},
#  {'lat': 42.5110055, 'lng': -92.4304734},
#  {'lat': 41.81832139999999, 'lng': -90.24385389999999},
#  {'lat': 41.5565045, 'lng': -93.5785011},
#  {'lat': 41.6141412, 'lng': -93.8342425},
#  {'lat': 41.4747764, 'lng': -93.6838958},
#  {'lat': 42.50665009999999, 'lng': -94.1860174},
#  {'lat': 41.65224550000001, 'lng': -91.57468399999999},
#  {'lat': 42.1865736, 'lng': -93.59807889999999},
#  {'lat': 42.2673438, 'lng': -94.5542024},
#  {'lat': 43.3847064, 'lng': -94.3087668},
#  {'lat': 41.3436337, 'lng': -94.0129796},
#  {'lat': 41.6534876, 'lng': -93.6013228},
#  {'lat': 42.5093036, 'lng': -92.4662485},
#  {'lat': 41.6071714, 'lng': -93.73593199999999},
#  {'lat': 42.8960184, 'lng': -92.80196769999999},
#  {'lat': 42.4692652, 'lng': -92.06265169999999},
#  {'lat': 42.50655709999999, 'lng': -94.156975},
#  {'lat': 42.4518122, 'lng': -91.8932875},
#  {'lat': 41.00629199999999, 'lng': -95.58514559999999},
#  {'lat': 40.6399673, 'lng': -91.7399085},
#  {'lat': 43.1291322, 'lng': -94.89915309999999},
#  {'lat': 42.7269386, 'lng': -92.4738608},
#  {'lat': 42.8535826, 'lng': -91.4047306},
#  {'lat': 42.0334232, 'lng': -91.6688952},
#  {'lat': 41.500616, 'lng': -91.5266688},
#  {'lat': 43.1633819, 'lng': -93.20162359999999},
#  {'lat': 42.4928574, 'lng': -90.7159427},
#  {'lat': 40.7460544, 'lng': -91.9586861},
#  {'lat': 41.355915, 'lng': -93.58753759999999},
#  {'lat': 42.6152994, 'lng': -91.9051345},
#  {'lat': 42.6456174, 'lng': -91.4014679},
#  {'lat': 42.6443082, 'lng': -95.1869392},
#  {'lat': 41.4036007, 'lng': -95.0138776},
#  {'lat': 42.0522419, 'lng': -93.62257179999999},
#  {'lat': 43.183993, 'lng': -95.32891819999999},
#  {'lat': 43.1331894, 'lng': -93.2020161},
#  {'lat': 42.0271893, 'lng': -93.6116296},
#  {'lat': 41.61562989999999, 'lng': -93.57858019999999},
#  {'lat': 41.2929926, 'lng': -92.64824329999999},
#  {'lat': 41.2966466, 'lng': -91.6946832},
#  {'lat': 43.00721679999999, 'lng': -95.9882664},
#  {'lat': 41.2798723, 'lng': -95.86885459999999},
#  {'lat': 41.9891569, 'lng': -91.649486},
#  {'lat': 43.3727408, 'lng': -95.1238841},
#  {'lat': 42.0201376, 'lng': -94.377994},
#  {'lat': 41.74340919999999, 'lng': -92.7232456},
#  {'lat': 41.5377297, 'lng': -90.573441},
#  {'lat': 42.471588, 'lng': -92.37727420000002},
#  {'lat': 41.5675513, 'lng': -90.6097959},
#  {'lat': 41.2258301, 'lng': -95.84388330000002},
#  {'lat': 41.325866, 'lng': -93.10727},
#  {'lat': 41.0274997, 'lng': -95.2337233},
#  {'lat': 41.5859821, 'lng': -92.5278912},
#  {'lat': 41.632919, 'lng': -91.5706455},
#  {'lat': 41.5093414, 'lng': -93.515943},
#  {'lat': 42.4762744, 'lng': -92.3233755},
#  {'lat': 42.4707176, 'lng': -96.3486365},
#  {'lat': 42.51615839999999, 'lng': -96.38525779999999},
#  {'lat': 41.9432506, 'lng': -91.74715119999999},
#  {'lat': 41.64356859999999, 'lng': -93.73688399999999},
#  {'lat': 41.2578559, 'lng': -95.9022823},
#  {'lat': 41.6300862, 'lng': -93.7830104},
#  {'lat': 41.9760998, 'lng': -91.6272795},
#  {'lat': 41.6048475, 'lng': -93.6010064},
#  {'lat': 42.4991059, 'lng': -92.38361049999999},
#  {'lat': 34.9486897, 'lng': -80.0582464},
#  {'lat': 42.4357003, 'lng': -92.2917058},
#  {'lat': 42.0655406, 'lng': -94.8514964},
#  {'lat': 41.2795659, 'lng': -91.3594706},
#  {'lat': 42.1993073, 'lng': -91.5320024},
#  {'lat': 41.90279090000001, 'lng': -91.2546067},
#  {'lat': 43.2852849, 'lng': -92.8116785},
#  {'lat': 41.2206381, 'lng': -95.8173576},
#  {'lat': 42.517453, 'lng': -96.40548969999999},
#  {'lat': 41.5610733, 'lng': -93.79745199999999},
#  {'lat': 41.6576104, 'lng': -91.537092},
#  {'lat': 42.3058172, 'lng': -93.30250740000001},
#  {'lat': 41.559293, 'lng': -90.599918},
#  {'lat': 42.0661375, 'lng': -94.8665685},
#  {'lat': 41.7395545, 'lng': -91.6084764},
#  {'lat': 41.7072566, 'lng': -91.66048909999999},
#  {'lat': 42.0321179, 'lng': -91.6249666},
#  {'lat': 41.6442299, 'lng': -93.698302},
#  {'lat': 41.0103554, 'lng': -92.44017529999999},
#  {'lat': 42.2247077, 'lng': -92.8746455},
#  {'lat': 41.5784711, 'lng': -91.2599972},
#  {'lat': 41.8947942, 'lng': -93.59718889999999},
#  {'lat': 41.5997739, 'lng': -90.34332599999999},
#  {'lat': 41.6283622, 'lng': -93.6171103},
#  {'lat': 40.8111349, 'lng': -91.10128399999999},
#  {'lat': 42.5047548, 'lng': -94.1560152},
#  {'lat': 42.8467536, 'lng': -94.85298619999999},
#  {'lat': 42.5870244, 'lng': -95.9668805},
#  {'lat': 42.4936458, 'lng': -96.4092332},
#  {'lat': 41.2656517, 'lng': -95.8394279},
#  {'lat': 41.5265142, 'lng': -90.59129999999999},
#  {'lat': 41.6011348, 'lng': -93.60144149999999},
#  {'lat': 42.0381875, 'lng': -93.8676607},
#  {'lat': 43.07786, 'lng': -96.177807},
#  {'lat': 42.4706809, 'lng': -96.3469863},
#  {'lat': 42.6463646, 'lng': -95.1958446},
#  {'lat': 42.0120542, 'lng': -92.90916960000001},
#  {'lat': 41.644632, 'lng': -93.5151532},
#  {'lat': 43.0860955, 'lng': -95.6246438},
#  {'lat': 42.53929919999999, 'lng': -90.6763596},
#  {'lat': 41.0501645, 'lng': -95.74434029999999},
#  {'lat': 42.014099, 'lng': -94.37429949999999},
#  {'lat': 40.7267825, 'lng': -95.03572059999999},
#  {'lat': 42.4884209, 'lng': -92.3462034},
#  {'lat': 42.0340157, 'lng': -91.62200920000001},
#  {'lat': 41.2625032, 'lng': -95.8547919},
#  {'lat': 41.5741422, 'lng': -90.5759363},
#  {'lat': 42.499913, 'lng': -90.697064},
#  {'lat': 41.5377656, 'lng': -90.63731519999999},
#  {'lat': 43.059787, 'lng': -96.1808738},
#  {'lat': 41.6579773, 'lng': -91.5285225},
#  {'lat': 40.4026258, 'lng': -91.38978759999999},
#  {'lat': 42.048941, 'lng': -93.62127079999999},
#  {'lat': 41.651003, 'lng': -93.495432},
#  {'lat': 42.0165883, 'lng': -93.1623186},
#  {'lat': 41.5717423, 'lng': -93.7320051},
#  {'lat': 43.30212090000001, 'lng': -96.4305213},
#  {'lat': 40.715404, 'lng': -94.2384221},
#  {'lat': 41.5709195, 'lng': -93.5973669},
#  {'lat': 40.7889504, 'lng': -91.1157607},
#  {'lat': 42.7508786, 'lng': -91.6750631},
#  {'lat': 42.5885739, 'lng': -94.8466758},
#  {'lat': 41.9832628, 'lng': -91.6678759},
#  {'lat': 42.3952576, 'lng': -94.63386709999999},
#  {'lat': 41.6499191, 'lng': -95.3384382},
#  {'lat': 41.4080754, 'lng': -95.01540179999999},
#  {'lat': 41.8783375, 'lng': -91.8346236},
#  {'lat': 40.7177669, 'lng': -91.4521537},
#  {'lat': 41.8338135, 'lng': -90.84041599999999},
#  {'lat': 41.5208256, 'lng': -93.1038129},
#  {'lat': 40.4020094, 'lng': -91.38890959999999},
#  {'lat': 41.0391826, 'lng': -95.7465211},
#  {'lat': 41.0075081, 'lng': -91.1706177},
#  {'lat': 42.50242679999999, 'lng': -93.26040569999999},
#  {'lat': 41.55508, 'lng': -93.5973471},
#  {'lat': 41.976351, 'lng': -91.6190711},
#  {'lat': 42.2613645, 'lng': -94.06856719999999},
#  {'lat': 42.4223408, 'lng': -94.15087659999999},
#  {'lat': 41.6926232, 'lng': -94.3574422},
#  {'lat': 41.5907093, 'lng': -93.7127718},
#  {'lat': 42.5162232, 'lng': -92.4462963},
#  {'lat': 41.9645063, 'lng': -91.7397754},
#  {'lat': 42.4980886, 'lng': -92.2935534},
#  {'lat': 41.031358, 'lng': -94.1973026},
#  {'lat': 43.15024680000001, 'lng': -93.25317679999999},
#  {'lat': 43.3864349, 'lng': -93.9456933},
#  {'lat': 43.200744, 'lng': -91.152509},
#  {'lat': 40.7990429, 'lng': -91.1390176},
#  {'lat': 43.08603960000001, 'lng': -91.56805489999999},
#  {'lat': 42.0225549, 'lng': -94.5519058},
#  {'lat': 42.0328381, 'lng': -91.59633029999999},
#  {'lat': 41.5252152, 'lng': -90.51789409999999},
#  {'lat': 41.2199114, 'lng': -95.86025839999999},
#  {'lat': 41.37166999999999, 'lng': -93.558674},
#  {'lat': 41.3458884, 'lng': -94.0225347},
#  {'lat': 41.6884962, 'lng': -93.7790374},
#  {'lat': 41.5470267, 'lng': -93.6458887},
#  {'lat': 41.763972, 'lng': -93.7175299},
#  {'lat': 42.5137663, 'lng': -92.3454514},
#  {'lat': 42.5009349, 'lng': -94.17111419999999},
#  {'lat': 41.59160869999999, 'lng': -94.87992210000002},
#  {'lat': 41.6290302, 'lng': -93.7118514},
#  {'lat': 42.51787239999999, 'lng': -94.5347451},
#  {'lat': 40.7350958, 'lng': -92.8747959},
#  {'lat': 42.8452613, 'lng': -93.6171883},
#  {'lat': 41.83876, 'lng': -94.08106509999999},
#  {'lat': 41.89526499999999, 'lng': -93.60077319999999},
#  {'lat': 41.6430766, 'lng': -95.7891219},
#  {'lat': 41.54293750000001, 'lng': -93.64454239999999},
#  {'lat': 40.9644759, 'lng': -91.54110299999999},
#  {'lat': 41.6558172, 'lng': -93.7358527},
#  {'lat': 42.5423287, 'lng': -96.35873529999999},
#  {'lat': 41.8656856, 'lng': -94.6783615},
#  {'lat': 42.4906543, 'lng': -96.4039923},
#  {'lat': 42.9930167, 'lng': -93.95737679999999},
#  {'lat': 41.0300078, 'lng': -92.811307},
#  {'lat': 41.686671, 'lng': -93.2463811},
#  {'lat': 41.6000297, 'lng': -93.8656664},
#  {'lat': 41.5457819, 'lng': -90.62017589999999},
#  {'lat': 43.37848109999999, 'lng': -92.92038869999999},
#  {'lat': 43.284217, 'lng': -93.2006742},
#  {'lat': 42.0443675, 'lng': -91.6727477},
#  {'lat': 42.5402946, 'lng': -92.4750701},
#  {'lat': 41.5003292, 'lng': -94.1236874},
#  {'lat': 42.3254549, 'lng': -92.601486},
#  {'lat': 41.1729205, 'lng': -91.1896838},
#  {'lat': 41.6300552, 'lng': -93.70046330000001},
#  {'lat': 42.063846, 'lng': -94.72928879999999},
#  {'lat': 42.3943693, 'lng': -94.6322024},
#  {'lat': 42.5044493, 'lng': -94.1812959},
#  {'lat': 41.6031849, 'lng': -93.7567615},
#  {'lat': 41.5738124, 'lng': -90.5985864},
#  {'lat': 42.4887761, 'lng': -92.33730179999999},
#  {'lat': 41.6445869, 'lng': -93.46395659999999},
#  {'lat': 42.4692753, 'lng': -93.83128160000001},
#  {'lat': 42.0112727, 'lng': -91.6640942},
#  {'lat': 41.71685739999999, 'lng': -93.6014811},
#  {'lat': 42.2408965, 'lng': -90.6807516},
#  {'lat': 42.76388619999999, 'lng': -93.36796249999999},
#  {'lat': 41.26308640000001, 'lng': -95.90244729999999},
#  {'lat': 42.0177653, 'lng': -93.3152072},
#  {'lat': 42.86775799999999, 'lng': -91.3847054},
#  {'lat': 41.5215458, 'lng': -90.57000320000002},
#  {'lat': 41.6719763, 'lng': -93.7370625},
#  {'lat': 41.8994369, 'lng': -93.52949129999999},
#  {'lat': 41.7974922, 'lng': -91.4901604},
#  {'lat': 42.6835241, 'lng': -91.53591899999999},
#  {'lat': 41.9644599, 'lng': -91.706638},
#  {'lat': 42.037582, 'lng': -92.911588},
#  {'lat': 41.918337, 'lng': -91.4012793},
#  {'lat': 42.0575532, 'lng': -92.9079409},
#  {'lat': 41.5286116, 'lng': -93.5979602},
#  {'lat': 41.6909778, 'lng': -92.0670942},
#  {'lat': 41.7323423, 'lng': -93.5995426},
#  {'lat': 41.5651754, 'lng': -93.88012719999999},
#  {'lat': 41.5900074, 'lng': -93.61329649999999},
#  {'lat': 41.6974886, 'lng': -90.5467979},
#  {'lat': 41.70111430000001, 'lng': -91.6093861},
#  {'lat': 42.4613706, 'lng': -95.1519373},
#  {'lat': 42.2674828, 'lng': -94.7338704},
#  {'lat': 43.1857344, 'lng': -95.65613309999999},
#  {'lat': 42.7121459, 'lng': -95.4371973},
#  {'lat': 41.5287237, 'lng': -90.48181749999999},
#  {'lat': 42.0487492, 'lng': -90.6627786},
#  {'lat': 42.3098566, 'lng': -93.5725897},
#  {'lat': 41.5390673, 'lng': -90.5218687},
#  {'lat': 41.6514361, 'lng': -91.5761967},
#  {'lat': 41.5377498, 'lng': -90.6002139},
#  {'lat': 41.5866861, 'lng': -93.66446289999999},
#  {'lat': 41.5389972, 'lng': -90.60050989999999},
#  {'lat': 43.4300822, 'lng': -96.1757143},
#  {'lat': 42.0163387, 'lng': -91.6331192},
#  {'lat': 41.6286984, 'lng': -93.731668},
#  {'lat': 42.4569492, 'lng': -90.77328179999999},
#  {'lat': 43.454949, 'lng': -95.3215647},
#  {'lat': 41.3629658, 'lng': -93.5587729},
#  {'lat': 43.4985441, 'lng': -96.5031434},
#  {'lat': 42.78767089999999, 'lng': -92.667507},
#  {'lat': 43.0578891, 'lng': -92.31207200000001},
#  {'lat': 42.5539329, 'lng': -93.05503759999999},
#  {'lat': 41.6268793, 'lng': -93.6155412},
#  {'lat': 42.4098697, 'lng': -92.4501007},
#  {'lat': 41.25949079999999, 'lng': -95.867226},
#  ...]

# %%
geo_coordinates = pd.DataFrame.from_dict(geo_record)

# %%
store_db = store_db.merge(geo_coordinates, how='outer', left_index=True, right_index=True)
store_db
# Out:
#       Store Number                            Store Name            Address  \
# 0             4197  fareway stores #014 / sergeant bluff        700  1st st
# 1             4156         fareway stores #412 / oelwein    102  2nd ave se
# 2             4312          i-80 liquor / council bluffs  2411 s 24th st #1
# 3             4169               super quick 2 / hubbell   1824 hubbell ave
# 4             4596      quik trip #534 / e university dm  2945 e university
# ...            ...                                   ...                ...
# 2685          5899                 fort dodge smoke shop     1923 5th ave s
# 2686          5930                       east post rd bp  1010 east post rd
# 2687          5947         johnson ave bp / cedar rapids   4830 johnson ave
# 2688          9946       rock river distillation company      3294 170th st
# 2689          5958                    bp fuel / waterloo   127 jefferson st
#
#                 City Zip Code         County  \
# 0     sergeant bluff    51054       woodbury
# 1            oelwein    50662        fayette
# 2     council bluffs    51501  pottawattamie
# 3         des moines    50317           polk
# 4         des moines    50317           polk
# ...              ...      ...            ...
# 2685      fort dodge    50501        webster
# 2686          marion    52302           linn
# 2687    cedar rapids    52405           linn
# 2688     rock rapids    51246           lyon
# 2689        waterloo    50701     black hawk
#
#                               Geo Address        lat        lng
# 0           700  1st st sergeant bluff IA  42.400155 -96.352688
# 1              102  2nd ave se oelwein IA  42.676933 -91.910791
# 2     2411 s 24th st #1 council bluffs IA  41.238208 -95.878339
# 3          1824 hubbell ave des moines IA  41.596324 -93.586509
# 4         2945 e university des moines IA  41.599999 -93.559356
# ...                                   ...        ...        ...
# 2685         1923 5th ave s fort dodge IA  42.500935 -94.171114
# 2686          1010 east post rd marion IA  42.020286 -91.598529
# 2687     4830 johnson ave cedar rapids IA  41.968531 -91.733484
# 2688         3294 170th st rock rapids IA  43.404758 -96.138057
# 2689         127 jefferson st waterloo IA  42.497587 -92.345008
#
# [2690 rows x 9 columns]

# %%
store_db['Address'].value_counts()
# need to figure out 1) whether the address has two stores, 2) what store numbers are for current open
# Out:
# 101 main st              5
# 315 fletcher ave         5
# 2635 adventureland dr    4
# 4335 texas st            4
# 1610 rockingham rd       4
#                         ..
# 1200 s 16th st           1
# 680 lindale dr           1
# 726 creek top            1
# 211, w 53rd st           1
# 127 jefferson st         1
# Name: Address, Length: 2469, dtype: int64

# %%
store_db.isna().sum()
# Out:
# index           0
# Store Number    0
# Store Name      0
# Address         0
# City            0
# Zip Code        0
# County          1
# Geo Address     0
# lat             0
# lng             0
# dtype: int64

# %% [markdown]
# - IF YOU RUN THIS NOTEBOOK FROM THE BEGINNING AGAIN, YOU MUST ADD A LINE TO FILL THE COUNTY NA VALUE, IT SHOULD BE 'cerro gordo'

# %%
store_db.isna().sum()
# Out:
# Store Number    0
# Store Name      0
# Address         0
# City            0
# Zip Code        0
# County          0
# Geo Address     0
# lat             0
# lng             0
# dtype: int64

# %%
# round up the coordinates
store_db['lat'] = round(store_db['lat'], 5)
store_db['lng'] = round(store_db['lng'], 5)

# %%
# lat should be in range between 40 and 44
# lng should be in range between -97 and -90
print(store_db['lat'].max())
print(store_db['lat'].min())
print(store_db['lng'].max())
print(store_db['lng'].min())
# Out:
# 45.3404
# 34.18712
# -79.76767
# -104.79994

# %%
store_db[(store_db['lat'] > 44) | (store_db['lat'] < 40) | (store_db['lng'] > -90) | (store_db['lng'] < -97)]
# Out:
#       Store Number                            Store Name  \
# 335           3782             bender foods / guttenberg
# 482           5153                oak street station llc
# 566           4525   casey's general store #2425 / akron
# 817           4607  casey's general store #1024 / gutten
# 1910          4672      the pit stop / river city liquor
# 1977          4008                  sioux valley spirits
# 2165          5814   eichman enterprises inc / sageville
#
#                    Address        City Zip Code    County  \
# 335           619 s hwy 52  guttenberg    52052   clayton
# 482         2403 us hwy 18      inwood    51240      lyon
# 566   600 highway 12 south       akron    51001  plymouth
# 817         1131, s hwy 52  guttenberg    52052   clayton
# 1910          402 s hwy 52  guttenberg    52052   clayton
# 1977         116 e main st      anthon    51004  woodbury
# 2165        11941 hwy 52 n   sageville    52002   dubuque
#
#                         Geo Address       lat        lng
# 335      619 s hwy 52 guttenberg IA  34.18712  -79.76767
# 482        2403 us hwy 18 inwood IA  42.75917 -104.79994
# 566   600 highway 12 south akron IA  45.34040  -97.51111
# 817    1131, s hwy 52 guttenberg IA  34.94869  -80.05825
# 1910     402 s hwy 52 guttenberg IA  39.54960  -85.36882
# 1977        116 e main st anthon IA  38.25565  -85.75078
# 2165    11941 hwy 52 n sageville IA  39.43356  -85.02459

# %% [markdown]
# 3782 lat:42.779662 lng: -91.1018998
# 5153 43.3009173 -96.4339502
# 4525 address = 79 South St, lat 42.8231254 lng -96.5630345
# 4607 42.7730642 -91.1020122
# 4672 42.7823886 -91.1005074
# 4008 42.3882855 -95.8669365
# 5814 42.5665731 -90.7206561

# %%
# when geocode couldn't find the actual coordinate, it will return the below values
print(round(41.8780025, 5))
print(round(-93.097702, 5))
# Out:
# 41.878
# -93.0977

# %%
store_db[(store_db['lat'] == 41.878) & (store_db['lng'] == -93.0977)]
# Out:
#       Store Number                  Store Name                     Address  \
# 12            2560  hy-vee food store / marion  3600 business hwy 151 east
# 1922          4101             lucky stop inc.    301 water st  po box 166
#
#            City Zip Code County                            Geo Address  \
# 12       marion    52302   linn   3600 business hwy 151 east marion IA
# 1922  cambridge    50046  story  301 water st  po box 166 cambridge IA
#
#          lat      lng
# 12    41.878 -93.0977
# 1922  41.878 -93.0977

# %% [markdown]
# 2560 42.037154 -91.5745887
# 4101 41.8994236 -93.5317064

# %%
store_db.loc[store_db['Store Number'] == 3782, ['lat', 'lng']] = [42.77966, -91.1019]
store_db.loc[store_db['Store Number'] == 5153, ['lat', 'lng']] = [43.30092, -96.43395]
store_db.loc[store_db['Store Number'] == 4525, ['lat', 'lng']] = [42.82313, -96.56303]
store_db.loc[store_db['Store Number'] == 4607, ['lat', 'lng']] = [42.77306, -91.10201]
store_db.loc[store_db['Store Number'] == 4672, ['lat', 'lng']] = [42.78239, -91.10051]
store_db.loc[store_db['Store Number'] == 4008, ['lat', 'lng']] = [42.38829, -95.86694]
store_db.loc[store_db['Store Number'] == 5814, ['lat', 'lng']] = [42.56657, -90.72066]
store_db.loc[store_db['Store Number'] == 2560, ['lat', 'lng']] = [42.03715, -91.57459]
store_db.loc[store_db['Store Number'] == 4101, ['lat', 'lng']] = [41.89942, -93.53171]

# %%
store_db[(store_db['lat'] > 44) | (store_db['lat'] < 40) | (store_db['lng'] > -90) | (store_db['lng'] < -97)]
# Out:
# Empty DataFrame
# Columns: [Store Number, Store Name, Address, City, Zip Code, County, Geo Address, lat, lng]
# Index: []

# %%
store_db[(store_db['lat'] == 41.878) & (store_db['lng'] == -93.0977)]
# Out:
# Empty DataFrame
# Columns: [Store Number, Store Name, Address, City, Zip Code, County, Geo Address, lat, lng]
# Index: []

# %%
store_db = store_db.drop(columns = ['Geo Address'])

# %%
store_db.sort_values(['Store Number'], inplace = True)

# %%
store_db
# Out:
#       Store Number                       Store Name                 Address  \
# 0             2106      hillstreet news and tobacco            2217 college
# 1             2113                   jamboree foods  1119 market st. box 71
# 2             2130             sycamore convenience            617 sycamore
# 3             2132                 spirits and such               100 e elm
# 4             2152               dugans supermarket           202 4th north
# ...            ...                              ...                     ...
# 2685          9931             lonely oak distilery        1833 elmwood rd.
# 2686          9934         cats eye distillery, llc   4860 heatherstone rd.
# 2687          9937       green frog distillery, llc         3345 270th ave.
# 2688          9938         templeton distilling llc            209 e 3rd st
# 2689          9946  rock river distillation company           3294 170th st
#
#              City Zip Code       County       lat       lng
# 0     cedar falls    50613   black hawk  42.51718 -92.45608
# 1          gowrie    50543      webster  42.28036 -94.28940
# 2        waterloo    50703   black hawk  42.49810 -92.33507
# 3      west union    52175      fayette  42.96115 -91.80796
# 4        rockwell    50469  cerro gordo  42.98635 -93.18789
# ...           ...      ...          ...       ...       ...
# 2685      earling    51530       shelby  41.77087 -95.47734
# 2686   bettendorf    52722        scott  41.57107 -90.45529
# 2687       keokuk    52632          lee  40.47283 -91.40092
# 2688    templeton    51463      carroll  41.91745 -94.93643
# 2689  rock rapids    51246         lyon  43.40476 -96.13806
#
# [2690 rows x 8 columns]

# %% [markdown]
# - See whether the store is currently running or shutdown

# %%
df.drop(df.loc[(df['Store Number'] == 5320) | (df['Store Number'] == 9932)].index, inplace=True)
df.drop(df.loc[df['County'] == 'el paso'].index, inplace=True)

# %%
store_date = df.groupby(['Store Number']).agg({'Date':['max', 'min']}).reset_index()
# Out:
#      Store Number       Date
#                          max        min
# 0            2106 2022-01-27 2012-01-05
# 1            2113 2020-02-03 2012-01-04
# 2            2130 2022-01-27 2012-01-05
# 3            2132 2012-04-23 2012-01-09
# 4            2152 2016-03-17 2012-01-09
# ...           ...        ...        ...
# 2685         9931 2018-07-06 2017-06-14
# 2686         9934 2018-01-25 2017-11-17
# 2687         9937 2018-05-23 2018-05-23
# 2688         9938 2018-07-26 2018-07-26
# 2689         9946 2020-10-15 2020-10-15
#
# [2690 rows x 3 columns]

# %%
store_date = store_date.sort_values(['Store Number'])
store_date
# Out:
#      Store Number       Date
#                          max        min
# 0            2106 2022-01-27 2012-01-05
# 1            2113 2020-02-03 2012-01-04
# 2            2130 2022-01-27 2012-01-05
# 3            2132 2012-04-23 2012-01-09
# 4            2152 2016-03-17 2012-01-09
# ...           ...        ...        ...
# 2685         9931 2018-07-06 2017-06-14
# 2686         9934 2018-01-25 2017-11-17
# 2687         9937 2018-05-23 2018-05-23
# 2688         9938 2018-07-26 2018-07-26
# 2689         9946 2020-10-15 2020-10-15
#
# [2690 rows x 3 columns]

# %%
store_db['max'] = store_date['Date']['max']
store_db['min'] = store_date['Date']['min']
store_db
# Out:
#       Store Number                       Store Name                 Address  \
# 0             2106      hillstreet news and tobacco            2217 college
# 1             2113                   jamboree foods  1119 market st. box 71
# 2             2130             sycamore convenience            617 sycamore
# 3             2132                 spirits and such               100 e elm
# 4             2152               dugans supermarket           202 4th north
# ...            ...                              ...                     ...
# 2685          9931             lonely oak distilery        1833 elmwood rd.
# 2686          9934         cats eye distillery, llc   4860 heatherstone rd.
# 2687          9937       green frog distillery, llc         3345 270th ave.
# 2688          9938         templeton distilling llc            209 e 3rd st
# 2689          9946  rock river distillation company           3294 170th st
#
#              City Zip Code       County       lat       lng        max  \
# 0     cedar falls    50613   black hawk  42.51718 -92.45608 2022-01-27
# 1          gowrie    50543      webster  42.28036 -94.28940 2020-02-03
# 2        waterloo    50703   black hawk  42.49810 -92.33507 2022-01-27
# 3      west union    52175      fayette  42.96115 -91.80796 2012-04-23
# 4        rockwell    50469  cerro gordo  42.98635 -93.18789 2016-03-17
# ...           ...      ...          ...       ...       ...        ...
# 2685      earling    51530       shelby  41.77087 -95.47734 2018-07-06
# 2686   bettendorf    52722        scott  41.57107 -90.45529 2018-01-25
# 2687       keokuk    52632          lee  40.47283 -91.40092 2018-05-23
# 2688    templeton    51463      carroll  41.91745 -94.93643 2018-07-26
# 2689  rock rapids    51246         lyon  43.40476 -96.13806 2020-10-15
#
#             min
# 0    2012-01-05
# 1    2012-01-04
# 2    2012-01-05
# 3    2012-01-09
# 4    2012-01-09
# ...         ...
# 2685 2017-06-14
# 2686 2017-11-17
# 2687 2018-05-23
# 2688 2018-07-26
# 2689 2020-10-15
#
# [2690 rows x 10 columns]

# %%
# assuming if there's an order within the last 1 mo, they are still open
store_db[store_db['max'] >= '2022-01-01']
# Out:
#       Store Number                         Store Name  \
# 0             2106        hillstreet news and tobacco
# 2             2130               sycamore convenience
# 7             2190          central city liquor, inc.
# 8             2191                     keokuk spirits
# 9             2200                   sac liquor store
# ...            ...                                ...
# 2661          9037         green frog distillery, llc
# 2663          9039         foundry distilling company
# 2664          9041               s&b farms distillery
# 2665          9042  american heritage distillers, llc
# 2667          9047        revelton distilling company
#
#                          Address             City Zip Code      County  \
# 0                   2217 college      cedar falls    50613  black hawk
# 2                   617 sycamore         waterloo    50703  black hawk
# 7                   1460 2nd ave       des moines    50314        polk
# 8                      1013 main           keokuk    52632         lee
# 9                  619 e main st         sac city    50583         sac
# ...                          ...              ...      ...         ...
# 2661              3345 270th ave           keokuk    52632         lee
# 2663  111 south 11th st. ste 100  west des moines    50265        polk
# 2664            212 e ramsey st.         bancroft    50517     kossuth
# 2665                 po box 1317          spencer    51301        clay
# 2667              1400 w clay st          osceola    50213      clarke
#
#            lat       lng        max        min
# 0     42.51718 -92.45608 2022-01-27 2012-01-05
# 2     42.49810 -92.33507 2022-01-27 2012-01-05
# 7     41.60565 -93.62024 2022-01-31 2012-01-03
# 8     40.40017 -91.38753 2022-01-27 2012-01-03
# 9     42.42166 -94.97412 2022-01-31 2012-01-04
# ...        ...       ...        ...        ...
# 2661  40.47283 -91.40092 2022-01-13 2018-05-23
# 2663  41.53435 -93.71764 2022-01-25 2018-11-09
# 2664  43.29281 -94.21542 2022-01-21 2018-10-12
# 2665  43.14507 -95.14432 2022-01-14 2019-03-28
# 2667  41.04071 -93.78681 2022-01-04 2020-12-17
#
# [1724 rows x 10 columns]

# %%
# newly open the has been running 7mo.
# maybe benchmarking these stores?
store_db[(store_db['max'] >= '2022-01-01') & (store_db['min'] >= '2021-07-01')]
# Out:
#       Store Number                                         Store Name  \
# 10            2201                   happy's wine & spirits wholesale
# 2455          6039             casey's general store #2879 / waterloo
# 2507          6093                             casey's #2741 / sidney
# 2576          6168                             brew oil #32 / spencer
# 2582          6175                         malcom gas & food / malcom
# ...            ...                                                ...
# 2645          6257                         station mart 2 / evansdale
# 2646          6258  fort madison tobacco and liquor outlet plus / ...
# 2647          6260           superquick liquor vine / west des moines
# 2648          6262          fareway stores, inc. #222 / rockwell city
# 2649          6263                          pump n pack / rock valley
#
#                      Address             City Zip Code      County       lat  \
# 10       5925 university ave      cedar falls    50613  black hawk  42.51235
# 2455     3260 university ave         waterloo    50701  black hawk  42.50119
# 2507          901 indiana st           sidney    51652     fremont  40.74849
# 2576            15 grand ave          spencer    51301        clay  43.13827
# 2582    203 montezuma street           malcom    50157   poweshiek  41.70645
# ...                      ...              ...      ...         ...       ...
# 2645  1119 river forest road        evansdale    50707  black hawk  42.46282
# 2646           1735 avenue h     fort madison    52627         lee  40.63050
# 2647        2704 vine street  west des moines    50265        polk  41.58006
# 2648    339 east high street    rockwell city    50579     calhoun  42.39796
# 2649        1004 main street      rock valley    51247       sioux  43.20018
#
#            lng        max        min
# 10   -92.42944 2022-01-27 2021-10-28
# 2455 -92.38852 2022-01-11 2021-07-28
# 2507 -95.64606 2022-01-21 2021-07-02
# 2576 -95.14512 2022-01-26 2021-08-11
# 2582 -92.55228 2022-01-28 2021-08-18
# ...        ...        ...        ...
# 2645 -92.29725 2022-01-25 2021-12-22
# 2646 -91.32979 2022-01-27 2022-01-05
# 2647 -93.74170 2022-01-24 2022-01-24
# 2648 -94.62450 2022-01-31 2022-01-24
# 2649 -96.29441 2022-01-25 2022-01-19
#
# [63 rows x 10 columns]

# %%
# newly open but shutdown
store_db[(store_db['max'] < '2021-12-01') & (store_db['min'] >= '2021-07-01')]
# Out:
#       Store Number                      Store Name  \
# 2637          6244  kwik star #1146 / cedar rapids
#
#                          Address          City Zip Code County       lat  \
# 2637  4201 16th avenue southwest  cedar rapids    52404   linn  41.96288
#
#            lng        max        min
# 2637 -91.72704 2021-11-22 2021-11-22

# %%
store_db.to_csv('Store DB.csv', index=False)

# %%
store_db.dtypes
# Out:
# Store Number      int64
# Store Name       object
# Address          object
# City             object
# Zip Code         object
# County           object
# lat             float64
# lng             float64
# max              object
# min              object
# dtype: object

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

# %%
store_db = pd.read_csv('Store DB.csv')

# %%
import json
# read county boundary information
us_geo = json.load(open('us-county-boundaries.json','r'))

# sort information only for Iowa
coords = []
for x in range(len(us_geo)):
    if us_geo[x]['fields']['stusab'] == 'IA':
        coords += us_geo[x]['fields']['geo_shape']['coordinates'][0]

# record it
a = np.array(coords)
IA_county_boundary = pd.DataFrame(a, columns = ['Lng','Lat'])

# %%
# Iowa county map + all stores (shutdown + running)
plt.figure(figsize = [12, 9])
plt.scatter(x=IA_county_boundary['Lng'], y=IA_county_boundary['Lat'], s=0.5)
plt.scatter(x=store_db['lng'], y=store_db['lat'], s=5)
plt.show()

# %%
# Iowa county map + new stores (still running only)
plt.figure(figsize = [12, 9])
plt.scatter(x=IA_county_boundary['Lng'], y=IA_county_boundary['Lat'], s=0.5)
plt.scatter(x=store_db[(store_db['max'] >= '2022-01-01') & (store_db['min'] >= '2021-07-01')]['lng'], y=store_db[(store_db['max'] >= '2022-01-01') & (store_db['min'] >= '2021-07-01')]['lat'], s=20)
plt.show()

# %%
# Iowa county map + current existing
plt.figure(figsize = [12, 9])
plt.scatter(x=IA_county_boundary['Lng'], y=IA_county_boundary['Lat'], s=0.5)
plt.scatter(x=store_db[(store_db['max'] >= '2022-01-01')]['lng'], y=store_db[(store_db['max'] >= '2022-01-01')]['lat'], s=5)
plt.show()
